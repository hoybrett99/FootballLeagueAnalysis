# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait

import time
import pandas as pd
import re
import logging

# %% [markdown]
# ## Setting up the chromedriver

# %%
service = Service()
option = webdriver.ChromeOptions()

# %%
driver = webdriver.Chrome(service=service, options=option)

# %%
URL = "https://en.onlinesoccermanager.com/Login?nextUrl=%2FDashboard"
driver.get(URL)

# %% [markdown]
# ## Navigating through the website

# %%
# Clicking the accept button
button_accept = driver.find_element(By.XPATH, "//button[contains(@class, 'btn-new btn-orange')]")
button_accept.click()

# %%
# Pressing the login button
button_log = driver.find_element(By.XPATH, "//button[contains(@class, 'btn-alternative')]")
button_log.click()

# %%
# Typing the login details
user = driver.find_element(By.XPATH, "//input[contains(@id, 'manager-name')]")
user.send_keys("rusty977")
password = driver.find_element(By.XPATH, "//input[contains(@id, 'password')]")
password.send_keys("Everest_79")

# %%
# Clicking the login button
button_enter = driver.find_element(By.XPATH, "//button[contains(@id, 'login')]")
button_enter.click()

# %%
# Clicking agree button
click_accept = driver.find_element(By.XPATH, "//p[contains(@class, 'fc-button-label')]")
click_accept.click()

# %%
# Choosing the first slot
club = driver.find_element(By.XPATH, "//div[contains(@class, 'clubslot-column')]")
club.click()

# %%
# Opening the match tab
match_menu = driver.find_element(By.XPATH, '//*[@id="desktop-menu-navbar"]/li[4]/a/div[2]')
match_menu.click()

# %%
# Opening the results page
result_page = driver.find_element(By.XPATH, "//*[@id='desktop-menu-navbar']/li[4]/ul/li[1]/a")
result_page.click()

# %% [markdown]
# ## Building the foundation of the webscraper

# %%
gameOne = driver.find_element(By.XPATH, '//div[contains(@class, "font-lg semi-bold")][contains(text(), "37")]')
gameOne.click()

# %%
# Creating a loop to click each page until game 1 is reached
for i in range(26, 0, -1):
    gameOne = driver.find_element(By.XPATH, f'//div[contains(@class, "button-arrow3-left")]')
    gameOne.click()
    print(f'Page: {i}')
    time.sleep(1)
# Out:
# Page: 26
# Page: 25
# Page: 24
# Page: 23
# Page: 22
# Page: 21
# Page: 20
# Page: 19
# Page: 18
# Page: 17
# Page: 16
# Page: 15
# Page: 14
# Page: 13
# Page: 12
# Page: 11
# Page: 10
# Page: 9
# Page: 8
# Page: 7
# Page: 6
# Page: 5
# Page: 4
# Page: 3
# Page: 2
# Page: 1

# %%
wait = WebDriverWait(driver, 5)

# %%
# Wait for the page to load and games to be visible
wait = WebDriverWait(driver, 5)

# Loop through each game
for i in range(1, 10):  # Assuming there are 9 games
    try:
        # Locate the game element using XPath
        game = wait.until(EC.element_to_be_clickable((By.XPATH, f'(//tr[@class="clickable"])[{i}]')))
        game.click()
        
        # Wait for 2 seconds
        time.sleep(2)
        
        # Locate and click the exit element (the close button with the 'x' icon)
        exit_button = wait.until(EC.element_to_be_clickable((By.XPATH, '//span[@class="fa fa-times"]')))
        exit_button.click()
        
        # Wait for any transition effects
        time.sleep(1)
        
    except Exception as e:
        print(f"An error occurred on game {i}: {e}")
# Out:
# An error occurred on game 9: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF62D5EB5D2+29090]
# 	(No symbol) [0x00007FF62D55E689]
# 	(No symbol) [0x00007FF62D41B1CA]
# 	(No symbol) [0x00007FF62D46EFD7]
# 	(No symbol) [0x00007FF62D46F22C]
# 	(No symbol) [0x00007FF62D4B97F7]
# 	(No symbol) [0x00007FF62D49672F]
# 	(No symbol) [0x00007FF62D4B65D9]
# 	(No symbol) [0x00007FF62D496493]
# 	(No symbol) [0x00007FF62D4609B1]
# 	(No symbol) [0x00007FF62D461B11]
# 	GetHandleVerifier [0x00007FF62D908C5D+3295277]
# 	GetHandleVerifier [0x00007FF62D954843+3605523]
# 	GetHandleVerifier [0x00007FF62D94A707+3564247]
# 	GetHandleVerifier [0x00007FF62D6A6EB6+797318]
# 	(No symbol) [0x00007FF62D56980F]
# 	(No symbol) [0x00007FF62D5653F4]
# 	(No symbol) [0x00007FF62D565580]
# 	(No symbol) [0x00007FF62D554A1F]
# 	BaseThreadInitThunk [0x00007FFEDB637374+20]
# 	RtlUserThreadStart [0x00007FFEDCDBCC91+33]

# %% [markdown]
# ## Collecting match summary

# %%
# Find all <tr> elements with the class 'clickable'
clickable_rows = driver.find_elements(By.XPATH, "//tr[contains(@class, 'clickable')]")

# Count the number of elements
clickable_count = len(clickable_rows) 
print(clickable_count)
# Out:
# 10

# %%
# Home team stats
homeTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[1]/div/div[2]/div').text
homeGoals = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeGoals']").text)
homeShots = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeChances']").text)
homeCorner = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeCorners']").text)
homeFoul = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeFouls']").text)
homePossession = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][contains(@data-bind, 'homePossession')]").text.rstrip('%'))
homeFormation = driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeFormationPartial().description']").text
homeYellow = int(driver.find_element(By.XPATH, "//span[@class='icon-player-yellowcard text-center'][contains(@data-bind, 'getEventCountForTeam(MatchEventType.YellowCard, $parent.homeTeamPartial()')]").text)
homeRed = int(driver.find_element(By.XPATH, "//span[@class='icon-player-redcard text-center'][contains(@data-bind, 'getEventCountForTeam(MatchEventType.RedCard, $parent.homeTeamPartial()')]").text)

# Away team stats
awayTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[3]/div/div[2]/div').text
awayGoals = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayGoals']").text)
awayShots = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayChances']").text)
awayCorner = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayCorners']").text)
awayFoul = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayFouls']").text)
awayPossession = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][contains(@data-bind, 'awayPossession')]").text.rstrip('%'))
awayFormation = driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayFormationPartial().description']").text
awayYellow = int(driver.find_element(By.XPATH, "//span[@class='icon-player-yellowcard text-center'][contains(@data-bind, 'getEventCountForTeam(MatchEventType.YellowCard, $parent.awayTeamPartial()')]").text)
awayRed = int(driver.find_element(By.XPATH, "//span[@class='icon-player-redcard text-center'][contains(@data-bind, 'getEventCountForTeam(MatchEventType.RedCard, $parent.awayTeamPartial()')]").text)

# Field stats
homeField = int(driver.find_element(By.XPATH, "//span[contains(@data-bind, 'fieldBalanceLeft')]").text.rstrip('%'))
centreField = int(driver.find_element(By.XPATH, "//div[contains(@data-bind, 'fieldBalanceMiddle')]").text.rstrip('%'))
awayField = int(driver.find_element(By.XPATH, "//div[contains(@data-bind, 'fieldBalanceRight')]").text.rstrip('%'))

# %%
# Initialising an empty dataframe
data = {
    'HomeTeam': [homeTeam],
    'AwayTeam':[awayTeam],
    'HomeGoals': [homeGoals],      
    'AwayGoals': [awayGoals],      
    'HomeShots': [homeShots],     
    'AwayShots': [awayShots],      
    'HomeCorner': [homeCorner],     
    'AwayCorner': [awayCorner],  
    'HomeFoul': [homeFoul],       
    'AwayFoul': [awayFoul],       
    'HomeYellow': [homeYellow],   
    'AwayYellow': [awayYellow],  
    'HomeRed': [homeRed],            
    'AwayRed': [awayRed],            
    'HomePossession': [homePossession],
    'AwayPossession': [awayPossession], 
    'HomeFormation': [homeFormation], 
    'AwayFormation': [awayFormation], 
    'HomeField': [homeField],         
    'CentreField': [centreField],     
    'AwayField': [awayField]         
}

df = pd.DataFrame(data)

# %%
df = pd.DataFrame()

# %%
# Initialising empty list
match_data = []

# %%
# Building a loop to collect match data in first page

# Loop through each game
for i in range(21, 39):

    time.sleep(3)

    # Find all <tr> elements with the class 'clickable'
    clickable_rows = driver.find_elements(By.XPATH, "//tr[contains(@class, 'clickable')]")

    # Count the number of elements
    clickable_count = len(clickable_rows)

    print(f'There are {clickable_count} games in this match')
    
    for j in range(1, clickable_count + 1):  # Assuming there are 9 games
        try:
            # Locate the game element using XPath
            game = wait.until(EC.element_to_be_clickable((By.XPATH, f'(//tr[contains(@class, "clickable")])[{j}]')))
            game.click()

            # Wait for 6 seconds
            time.sleep(4)

            # Home team stats
            homeTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[1]/div/div[2]/div').text
            homeGoals = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeGoals']").text)
            homeShots = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeChances']").text)
            homeCorner = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeCorners']").text)
            homeFoul = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeFouls']").text)
            homePossession = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][contains(@data-bind, 'homePossession')]").text.rstrip('%'))
            homeFormation = driver.find_element(By.XPATH, "//td[@class='td-match-stat-home text-right semi-bold'][@data-bind='text: homeFormationPartial().description']").text
            homeYellow = int(driver.find_element(By.XPATH, "//span[@class='icon-player-yellowcard text-center'][contains(@data-bind, 'getEventCountForTeam(MatchEventType.YellowCard, $parent.homeTeamPartial()')]").text)
            homeRed = int(driver.find_element(By.XPATH, "//span[@class='icon-player-redcard text-center'][contains(@data-bind, 'getEventCountForTeam(MatchEventType.RedCard, $parent.homeTeamPartial()')]").text)

            # Away team stats
            awayTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[3]/div/div[2]/div').text
            awayGoals = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayGoals']").text)
            awayShots = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayChances']").text)
            awayCorner = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayCorners']").text)
            awayFoul = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayFouls']").text)
            awayPossession = int(driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][contains(@data-bind, 'awayPossession')]").text.rstrip('%'))
            awayFormation = driver.find_element(By.XPATH, "//td[@class='td-match-stat-away semi-bold'][@data-bind='text: awayFormationPartial().description']").text
            awayYellow = int(driver.find_element(By.XPATH, "//span[@class='icon-player-yellowcard text-center'][contains(@data-bind, 'getEventCountForTeam(MatchEventType.YellowCard, $parent.awayTeamPartial()')]").text)
            awayRed = int(driver.find_element(By.XPATH, "//span[@class='icon-player-redcard text-center'][contains(@data-bind, 'getEventCountForTeam(MatchEventType.RedCard, $parent.awayTeamPartial()')]").text)

            # Field stats
            homeField = int(driver.find_element(By.XPATH, "//span[contains(@data-bind, 'fieldBalanceLeft')]").text.rstrip('%'))
            centreField = int(driver.find_element(By.XPATH, "//div[contains(@data-bind, 'fieldBalanceMiddle')]").text.rstrip('%'))
            awayField = int(driver.find_element(By.XPATH, "//div[contains(@data-bind, 'fieldBalanceRight')]").text.rstrip('%'))

            # Create a dictionary with the extracted data
            game_data = {
                'match': i,
                'HomeTeam': homeTeam,
                'AwayTeam': awayTeam,
                'HomeGoals': homeGoals,
                'AwayGoals': awayGoals,
                'HomeShots': homeShots,
                'AwayShots': awayShots,
                'HomeCorner': homeCorner,
                'AwayCorner': awayCorner,
                'HomeFoul': homeFoul,
                'AwayFoul': awayFoul,
                'HomeYellow': homeYellow,
                'AwayYellow': awayYellow,
                'HomeRed': homeRed,
                'AwayRed': awayRed,
                'HomePossession': homePossession,
                'AwayPossession': awayPossession,
                'HomeFormation': homeFormation,
                'AwayFormation': awayFormation,
                'HomeField': homeField,
                'CentreField': centreField,
                'AwayField': awayField
            }
            
            # Append data to the list
            match_data.append(game_data)

            # Displaying the progress
            print(f"Match {i} - Game {j}: {homeTeam} {homeGoals} - {awayGoals} {awayTeam}")
            
            
            # Wait for 2.5 seconds
            time.sleep(1.5)
            
            # Locate and click the exit element (the close button with the 'x' icon)
            exit_button = wait.until(EC.element_to_be_clickable((By.XPATH, '//span[@class="fa fa-times"]')))
            exit_button.click()
            
            # Wait for any transition effects
            time.sleep(2)
            
        except Exception as e:
            print(f"An error occurred on game {i}: {e}")


    try:
        matchPage = wait.until(EC.element_to_be_clickable((By.XPATH, '//div[contains(@class, "button-arrow3-right")]')))
        matchPage.click()
        print(f'Moved to Match: {i + 1}')
        time.sleep(1.5)
    except Exception as e:
        print(f"Error moving to next match page: {e}")
        break  # Exit the loop if we can't move to the next page
# Out:
# There are 9 games in this match
# Match 21 - Game 1: FC Groningen 0 - 1 Ajax
# Match 21 - Game 2: PEC Zwolle 0 - 4 NEC Nijmegen
# Match 21 - Game 3: Feyenoord 1 - 0 Sparta Rotterdam
# Match 21 - Game 4: RKC Waalwijk 0 - 4 NAC Breda
# Match 21 - Game 5: AZ 1 - 5 Go Ahead Eagles
# Match 21 - Game 6: PSV 0 - 0 Fortuna Sittard
# Match 21 - Game 7: SC Heerenveen 4 - 0 FC Utrecht
# Match 21 - Game 8: Almere City 0 - 4 Willem II
# Match 21 - Game 9: FC Twente 1 - 1 Heracles Almelo
# Moved to Match: 22
# There are 9 games in this match
# Match 22 - Game 1: FC Utrecht 6 - 1 Almere City
# Match 22 - Game 2: Willem II 4 - 0 AZ
# Match 22 - Game 3: Go Ahead Eagles 3 - 0 RKC Waalwijk
# Match 22 - Game 4: Fortuna Sittard 2 - 1 Feyenoord
# Match 22 - Game 5: NEC Nijmegen 0 - 1 FC Twente
# Match 22 - Game 6: Ajax 2 - 0 PEC Zwolle
# Match 22 - Game 7: Sparta Rotterdam 0 - 6 SC Heerenveen
# Match 22 - Game 8: Heracles Almelo 0 - 1 FC Groningen
# Match 22 - Game 9: NAC Breda 1 - 0 PSV
# Moved to Match: 23
# There are 9 games in this match
# Match 23 - Game 1: PSV 1 - 0 AZ
# Match 23 - Game 2: SC Heerenveen 1 - 4 NEC Nijmegen
# Match 23 - Game 3: Almere City 4 - 0 Sparta Rotterdam
# Match 23 - Game 4: PEC Zwolle 0 - 2 Feyenoord
# Match 23 - Game 5: Ajax 7 - 0 NAC Breda
# Match 23 - Game 6: FC Twente 0 - 5 Go Ahead Eagles
# Match 23 - Game 7: RKC Waalwijk 0 - 1 Fortuna Sittard
# Match 23 - Game 8: FC Groningen 0 - 1 Willem II
# Match 23 - Game 9: FC Utrecht 3 - 1 Heracles Almelo
# Moved to Match: 24
# There are 9 games in this match
# Match 24 - Game 1: Go Ahead Eagles 2 - 0 Almere City
# Match 24 - Game 2: NEC Nijmegen 1 - 4 Ajax
# Match 24 - Game 3: Heracles Almelo 5 - 1 RKC Waalwijk
# Match 24 - Game 4: Sparta Rotterdam 1 - 1 FC Twente
# Match 24 - Game 5: Fortuna Sittard 4 - 0 PEC Zwolle
# Match 24 - Game 6: Feyenoord 2 - 4 SC Heerenveen
# Match 24 - Game 7: AZ 0 - 2 FC Groningen
# Match 24 - Game 8: Willem II 0 - 0 PSV
# Match 24 - Game 9: NAC Breda 1 - 1 FC Utrecht
# Moved to Match: 25
# There are 9 games in this match
# Match 25 - Game 1: RKC Waalwijk 0 - 3 AZ
# Match 25 - Game 2: Fortuna Sittard 0 - 1 NEC Nijmegen
# Match 25 - Game 3: NAC Breda 2 - 0 Sparta Rotterdam
# Match 25 - Game 4: Almere City 1 - 2 Feyenoord
# Match 25 - Game 5: Ajax 3 - 0 FC Twente
# Match 25 - Game 6: FC Groningen 0 - 4 SC Heerenveen
# Match 25 - Game 7: PEC Zwolle 1 - 2 Go Ahead Eagles
# Match 25 - Game 8: FC Utrecht 1 - 2 Willem II
# Match 25 - Game 9: PSV 3 - 0 Heracles Almelo
# Moved to Match: 26
# There are 2 games in this match
# Match 26 - Game 1: SC Heerenveen 5 - 1 Feyenoord
# Match 26 - Game 2: Willem II 0 - 2 Go Ahead Eagles
# Moved to Match: 27
# There are 9 games in this match
# Match 27 - Game 1: Willem II 3 - 3 Ajax
# Match 27 - Game 2: Feyenoord 1 - 2 RKC Waalwijk
# Match 27 - Game 3: AZ 0 - 0 PEC Zwolle
# Match 27 - Game 4: SC Heerenveen 3 - 0 NAC Breda
# Match 27 - Game 5: Almere City 0 - 3 FC Groningen
# Match 27 - Game 6: Sparta Rotterdam 0 - 1 PSV
# Match 27 - Game 7: FC Twente 0 - 0 Fortuna Sittard
# Match 27 - Game 8: NEC Nijmegen 3 - 0 FC Utrecht
# Match 27 - Game 9: Go Ahead Eagles 2 - 0 Heracles Almelo
# Moved to Match: 28
# There are 9 games in this match
# Match 28 - Game 1: RKC Waalwijk 1 - 3 Almere City
# Match 28 - Game 2: NEC Nijmegen 1 - 1 AZ
# Match 28 - Game 3: FC Utrecht 6 - 0 Sparta Rotterdam
# Match 28 - Game 4: PSV 2 - 0 Feyenoord
# Match 28 - Game 5: PEC Zwolle 0 - 0 FC Twente
# Match 28 - Game 6: Ajax 1 - 2 SC Heerenveen
# Match 28 - Game 7: Fortuna Sittard 0 - 2 Go Ahead Eagles
# Match 28 - Game 8: NAC Breda 0 - 1 FC Groningen
# Match 28 - Game 9: Heracles Almelo 0 - 3 Willem II
# Moved to Match: 29
# There are 9 games in this match
# Match 29 - Game 1: Go Ahead Eagles 3 - 0 Ajax
# Match 29 - Game 2: Sparta Rotterdam 0 - 1 NEC Nijmegen
# Match 29 - Game 3: FC Groningen 5 - 0 RKC Waalwijk
# Match 29 - Game 4: Almere City 0 - 1 PEC Zwolle
# Match 29 - Game 5: Willem II 3 - 1 NAC Breda
# Match 29 - Game 6: FC Twente 3 - 0 PSV
# Match 29 - Game 7: AZ 0 - 1 Fortuna Sittard
# Match 29 - Game 8: Feyenoord 1 - 0 FC Utrecht
# Match 29 - Game 9: SC Heerenveen 4 - 0 Heracles Almelo
# Moved to Match: 30
# There are 9 games in this match
# Match 30 - Game 1: AZ 3 - 0 Almere City
# Match 30 - Game 2: RKC Waalwijk 0 - 6 Ajax
# Match 30 - Game 3: Fortuna Sittard 1 - 1 Sparta Rotterdam
# Match 30 - Game 4: NEC Nijmegen 3 - 0 Feyenoord
# Match 30 - Game 5: FC Utrecht 0 - 3 FC Twente
# Match 30 - Game 6: Heracles Almelo 1 - 0 PEC Zwolle
# Match 30 - Game 7: Willem II 0 - 1 SC Heerenveen
# Match 30 - Game 8: NAC Breda 0 - 3 Go Ahead Eagles
# Match 30 - Game 9: PSV 2 - 3 FC Groningen
# Moved to Match: 31
# There are 9 games in this match
# Match 31 - Game 1: Sparta Rotterdam 1 - 0 AZ
# Match 31 - Game 2: FC Groningen 0 - 3 NEC Nijmegen
# Match 31 - Game 3: SC Heerenveen 8 - 0 RKC Waalwijk
# Match 31 - Game 4: FC Twente 2 - 0 NAC Breda
# Match 31 - Game 5: Ajax 5 - 0 PSV
# Match 31 - Game 6: Almere City 0 - 2 Fortuna Sittard
# Match 31 - Game 7: Go Ahead Eagles 2 - 0 FC Utrecht
# Match 31 - Game 8: PEC Zwolle 1 - 2 Willem II
# Match 31 - Game 9: Feyenoord 2 - 0 Heracles Almelo
# Moved to Match: 32
# There are 9 games in this match
# Match 32 - Game 1: NEC Nijmegen 4 - 1 Almere City
# Match 32 - Game 2: Heracles Almelo 0 - 4 Ajax
# Match 32 - Game 3: Willem II 2 - 0 Feyenoord
# Match 32 - Game 4: FC Twente 0 - 1 AZ
# Match 32 - Game 5: NAC Breda 3 - 2 PEC Zwolle
# Match 32 - Game 6: Fortuna Sittard 0 - 3 SC Heerenveen
# Match 32 - Game 7: Sparta Rotterdam 0 - 5 Go Ahead Eagles
# Match 32 - Game 8: FC Utrecht 1 - 2 FC Groningen
# Match 32 - Game 9: PSV 5 - 0 RKC Waalwijk
# Moved to Match: 33
# There are 9 games in this match
# Match 33 - Game 1: FC Twente 2 - 0 Almere City
# Match 33 - Game 2: Feyenoord 3 - 0 AZ
# Match 33 - Game 3: Go Ahead Eagles 5 - 0 NEC Nijmegen
# Match 33 - Game 4: PEC Zwolle 1 - 1 Sparta Rotterdam
# Match 33 - Game 5: Heracles Almelo 3 - 0 NAC Breda
# Match 33 - Game 6: SC Heerenveen 4 - 0 PSV
# Match 33 - Game 7: FC Groningen 1 - 1 Fortuna Sittard
# Match 33 - Game 8: Ajax 1 - 0 FC Utrecht
# Match 33 - Game 9: RKC Waalwijk 0 - 7 Willem II
# Moved to Match: 34
# There are 9 games in this match
# Match 34 - Game 1: AZ 0 - 4 Ajax
# Match 34 - Game 2: PEC Zwolle 4 - 1 RKC Waalwijk
# Match 34 - Game 3: Go Ahead Eagles 4 - 0 Feyenoord
# Match 34 - Game 4: FC Twente 0 - 1 SC Heerenveen
# Match 34 - Game 5: Almere City 0 - 1 NAC Breda
# Match 34 - Game 6: Sparta Rotterdam 1 - 5 FC Groningen
# Match 34 - Game 7: FC Utrecht 1 - 3 PSV
# Match 34 - Game 8: Fortuna Sittard 2 - 4 Willem II
# Match 34 - Game 9: NEC Nijmegen 3 - 1 Heracles Almelo
# Moved to Match: 35
# There are 9 games in this match
# Match 35 - Game 1: SC Heerenveen 4 - 0 Almere City
# Match 35 - Game 2: Heracles Almelo 1 - 1 AZ
# Match 35 - Game 3: Willem II 7 - 1 NEC Nijmegen
# Match 35 - Game 4: Ajax 7 - 0 Sparta Rotterdam
# Match 35 - Game 5: Feyenoord 0 - 0 FC Twente
# Match 35 - Game 6: FC Groningen 1 - 0 PEC Zwolle
# Match 35 - Game 7: PSV 0 - 5 Go Ahead Eagles
# Match 35 - Game 8: NAC Breda 0 - 4 Fortuna Sittard
# Match 35 - Game 9: FC Utrecht 5 - 0 RKC Waalwijk
# Moved to Match: 36
# There are 9 games in this match
# Match 36 - Game 1: Fortuna Sittard 0 - 5 Ajax
# Match 36 - Game 2: FC Twente 3 - 0 RKC Waalwijk
# Match 36 - Game 3: AZ 0 - 2 SC Heerenveen
# Match 36 - Game 4: NEC Nijmegen 3 - 0 NAC Breda
# Match 36 - Game 5: Feyenoord 0 - 3 FC Groningen
# Match 36 - Game 6: Almere City 1 - 2 PSV
# Match 36 - Game 7: PEC Zwolle 0 - 0 FC Utrecht
# Match 36 - Game 8: Go Ahead Eagles 2 - 0 Willem II
# Match 36 - Game 9: Sparta Rotterdam 1 - 1 Heracles Almelo
# Moved to Match: 37
# There are 9 games in this match
# Match 37 - Game 1: Heracles Almelo 3 - 1 Almere City
# Match 37 - Game 2: NAC Breda 0 - 3 AZ
# Match 37 - Game 3: RKC Waalwijk 0 - 3 NEC Nijmegen
# Match 37 - Game 4: Willem II 5 - 1 Sparta Rotterdam
# Match 37 - Game 5: Ajax 2 - 0 Feyenoord
# Match 37 - Game 6: FC Groningen 4 - 0 FC Twente
# Match 37 - Game 7: PSV 2 - 1 PEC Zwolle
# Match 37 - Game 8: SC Heerenveen 2 - 0 Go Ahead Eagles
# Match 37 - Game 9: FC Utrecht 1 - 3 Fortuna Sittard
# Moved to Match: 38
# There are 1 games in this match
# Match 38 - Game 1: SC Heerenveen 0 - 4 Go Ahead Eagles
# Moved to Match: 39

# %%
# Create a DataFrame from match_data list
df = pd.DataFrame(match_data)
df.head(10)
# Out:
#    match          HomeTeam       AwayTeam  HomeGoals  AwayGoals  HomeShots  \
# 0      1              Ajax   FC Groningen          2          1         14
# 1      1      NEC Nijmegen     PEC Zwolle          3          0         16
# 2      1  Sparta Rotterdam      Feyenoord          0          1          9
# 3      1         NAC Breda   RKC Waalwijk          2          0         15
# 4      1   Go Ahead Eagles             AZ          0          0         13
# 5      1   Fortuna Sittard            PSV          0          2          7
# 6      1        FC Utrecht  SC Heerenveen          2          0         13
# 7      1         Willem II    Almere City          1          0          8
# 8      1   Heracles Almelo      FC Twente          3          0         14
# 9      2       Almere City     FC Utrecht          1          3          5
#
#    AwayShots  HomeCorner  AwayCorner  HomeFoul  ...  AwayYellow  HomeRed  \
# 0         11           5           5        15  ...           2        0
# 1          6           8           4        13  ...           2        0
# 2         12           3           3        10  ...           1        0
# 3          5          10           4        11  ...           1        0
# 4          7           4           1        16  ...           0        0
# 5         16           1          10        15  ...           1        0
# 6          8           5           6        13  ...           0        0
# 7          6           4           4        14  ...           1        0
# 8         15           7           8        12  ...           1        0
# 9         12           4           7        12  ...           2        0
#
#    AwayRed  HomePossession  AwayPossession  HomeFormation  AwayFormation  \
# 0        0              57              43        4-3-3 B        4-3-3 A
# 1        0              63              37        4-3-3 A        4-3-3 B
# 2        0              41              59        4-3-3 A        4-4-2 B
# 3        0              62              38        4-4-2 B        4-3-3 B
# 4        0              60              40        4-3-3 B        4-3-3 B
# 5        0              30              70        4-4-2 B        4-3-3 A
# 6        0              60              40        4-3-3 A        4-3-3 B
# 7        0              59              41        4-3-3 A        4-2-3-1
# 8        0              52              48        4-3-3 B        4-3-3 B
# 9        0              31              69        4-3-3 A        4-3-3 A
#
#   HomeField CentreField  AwayField
# 0        23          49         28
# 1        15          53         32
# 2        25          55         20
# 3        16          55         29
# 4        18          56         26
# 5        33          51         16
# 6        20          54         26
# 7        17          64         19
# 8        29          44         27
# 9        27          59         14
#
# [10 rows x 22 columns]

# %%
# Exporting the data
df.to_csv("D:\Webscraping\match_summary.csv", index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\hoybr\AppData\Local\Temp\ipykernel_32800\3343539991.py:2: SyntaxWarning: invalid escape sequence '\W'
#   df.to_csv("D:\Webscraping\match_summary.csv", index=False)

# %% [markdown]
# ## Collecting player ratings

# %%
table = wait.until(EC.presence_of_element_located((By.XPATH, "//table")))
table
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="cd9cde486f8b3e4e4ba9878df68c925c", element="f.0BC0809B969B8EA8C9FB03610C81D9C6.d.2C56806D73D3CCF9233A0613299F5B05.e.1275031")>

# %%
# Find all rows
rows = table.find_elements(By.XPATH, ".//tr")

# %%
# Wait for the match details to be present
wait = WebDriverWait(driver, 10)
match_details = wait.until(EC.presence_of_element_located((By.ID, "match-details")))

# Extract home and away team names
homeTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[1]/div/div[2]/div').text
awayTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[3]/div/div[2]/div').text

# Wait for the player grade tables to be present
away_table = wait.until(EC.presence_of_element_located((By.CLASS_NAME, "table-playergrades-away")))
home_table = wait.until(EC.presence_of_element_located((By.CLASS_NAME, "table-playergrades-home")))

def extract_player_data(table, team, home_or_away, match, game):
    rows = table.find_elements(By.TAG_NAME, "tr")
    player_data = []
    for row in rows:
        try:
            rating = row.find_element(By.XPATH, ".//span[@data-bind=\"text: playerGradePartial().grade > 0 ? playerGradePartial().grade.toFixed(0): '-'\"]").text
            name = row.find_element(By.XPATH, ".//div[@class='semi-bold'][@data-bind=\"text: nameWithSquadNumberForMatch()\"]").text
            
            # Remove only the first occurrence of digits followed by a period
            name = re.sub(r'^\d+\.\s*', '', name)
            
            player_data.append({
                "Match": match,
                "Game": game,
                "Team": team,
                "Home_or_Away": home_or_away,
                "Rating": rating,
                "Name": name
                    })
        except Exception as e:
            print(f"Error processing row: {e}")
    return player_data

# %%
# Extract data for away team
away_players = extract_player_data(away_table, awayTeam, "Away")

# Extract data for home team
home_players = extract_player_data(home_table, homeTeam, "Home")

# Combine the data
all_players = away_players + home_players

# Create a DataFrame
df = pd.DataFrame(all_players)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[239], line 2
#       1 # Extract data for away team
# ----> 2 away_players = extract_player_data(away_table, awayTeam, "Away")
#       4 # Extract data for home team
#       5 home_players = extract_player_data(home_table, homeTeam, "Home")
#
# TypeError: extract_player_data() missing 2 required positional arguments: 'match' and 'game'

# %%
df = pd.DataFrame(columns=["Match", "Game", "Team", "Home_or_Away", "Name", "Rating"])

# %%
# Building a loop to collect match data in first page

# Loop through each game
for i in range(20, 39):

    time.sleep(3)

    # Find all <tr> elements with the class 'clickable'
    clickable_rows = driver.find_elements(By.XPATH, "//tr[contains(@class, 'clickable')]")

    # Count the number of elements
    clickable_count = len(clickable_rows)

    print(f'There are {clickable_count} games in this match')
    
    for j in range(1, clickable_count + 1):  # Assuming there are 9 games
        try:
            # Locate the game element using XPath
            game = wait.until(EC.element_to_be_clickable((By.XPATH, f'(//tr[contains(@class, "clickable")])[{j}]')))
            game.click()

            # Wait for 6 seconds
            time.sleep(4)

            # Extract home and away team names
            homeTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[1]/div/div[2]/div').text
            awayTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[3]/div/div[2]/div').text

            # Wait for the player grade tables to be present
            away_table = wait.until(EC.presence_of_element_located((By.CLASS_NAME, "table-playergrades-away")))
            home_table = wait.until(EC.presence_of_element_located((By.CLASS_NAME, "table-playergrades-home")))


            # Extract data for away team
            away_players = extract_player_data(away_table, awayTeam, "Away", i, j)

            # Extract data for home team
            home_players = extract_player_data(home_table, homeTeam, "Home", i, j)

            # Combine the data
            all_players = away_players + home_players

            # Create a DataFrame
            df_players = pd.DataFrame(all_players)

            # Adding to dataframe
            df = pd.concat([df, df_players], ignore_index=True)

            
            # Displaying the progress
            print(f"Match {i} - Game {j}: {homeTeam} - {awayTeam}")
            
            
            # Wait for 2.5 seconds
            time.sleep(1.5)
            
            # Locate and click the exit element (the close button with the 'x' icon)
            exit_button = wait.until(EC.element_to_be_clickable((By.XPATH, '//span[@class="fa fa-times"]')))
            exit_button.click()
            
            # Wait for any transition effects
            time.sleep(2)
            
        except Exception as e:
            print(f"An error occurred on Match {i}, Game {j}: {e}")



    try:
        matchPage = wait.until(EC.element_to_be_clickable((By.XPATH, '//div[contains(@class, "button-arrow3-right")]')))
        matchPage.click()
        print(f'Moved to Match: {i + 1}')
        time.sleep(1.5)
    except Exception as e:
        print(f"Error moving to next match page: {e}")
        break  # Exit the loop if we can't move to the next page
# Out:
# There are 9 games in this match
# Match 20 - Game 1: Ajax - Almere City
# Match 20 - Game 2: RKC Waalwijk - Sparta Rotterdam
# Match 20 - Game 3: SC Heerenveen - PEC Zwolle
# Match 20 - Game 4: NAC Breda - Feyenoord
# Match 20 - Game 5: FC Groningen - Go Ahead Eagles
# Match 20 - Game 6: PSV - NEC Nijmegen
# Match 20 - Game 7: FC Utrecht - AZ
# Match 20 - Game 8: Willem II - FC Twente
# Match 20 - Game 9: Heracles Almelo - Fortuna Sittard
# Moved to Match: 21
# There are 9 games in this match
# Match 21 - Game 1: FC Groningen - Ajax
# Match 21 - Game 2: PEC Zwolle - NEC Nijmegen
# Match 21 - Game 3: Feyenoord - Sparta Rotterdam
# Match 21 - Game 4: RKC Waalwijk - NAC Breda
# Match 21 - Game 5: AZ - Go Ahead Eagles
# Match 21 - Game 6: PSV - Fortuna Sittard
# Match 21 - Game 7: SC Heerenveen - FC Utrecht
# Match 21 - Game 8: Almere City - Willem II
# Match 21 - Game 9: FC Twente - Heracles Almelo
# Moved to Match: 22
# There are 9 games in this match
# Match 22 - Game 1: FC Utrecht - Almere City
# Match 22 - Game 2: Willem II - AZ
# Match 22 - Game 3: Go Ahead Eagles - RKC Waalwijk
# Match 22 - Game 4: Fortuna Sittard - Feyenoord
# Match 22 - Game 5: NEC Nijmegen - FC Twente
# Match 22 - Game 6: Ajax - PEC Zwolle
# Match 22 - Game 7: Sparta Rotterdam - SC Heerenveen
# Match 22 - Game 8: Heracles Almelo - FC Groningen
# Match 22 - Game 9: NAC Breda - PSV
# Moved to Match: 23
# There are 9 games in this match
# Match 23 - Game 1: PSV - AZ
# Match 23 - Game 2: SC Heerenveen - NEC Nijmegen
# Match 23 - Game 3: Almere City - Sparta Rotterdam
# Match 23 - Game 4: PEC Zwolle - Feyenoord
# Match 23 - Game 5: Ajax - NAC Breda
# Match 23 - Game 6: FC Twente - Go Ahead Eagles
# Match 23 - Game 7: RKC Waalwijk - Fortuna Sittard
# Match 23 - Game 8: FC Groningen - Willem II
# Match 23 - Game 9: FC Utrecht - Heracles Almelo
# Moved to Match: 24
# There are 9 games in this match
# Match 24 - Game 1: Go Ahead Eagles - Almere City
# Match 24 - Game 2: NEC Nijmegen - Ajax
# Match 24 - Game 3: Heracles Almelo - RKC Waalwijk
# Match 24 - Game 4: Sparta Rotterdam - FC Twente
# Match 24 - Game 5: Fortuna Sittard - PEC Zwolle
# Match 24 - Game 6: Feyenoord - SC Heerenveen
# Match 24 - Game 7: AZ - FC Groningen
# Match 24 - Game 8: Willem II - PSV
# Match 24 - Game 9: NAC Breda - FC Utrecht
# Moved to Match: 25
# There are 9 games in this match
# Match 25 - Game 1: RKC Waalwijk - AZ
# Match 25 - Game 2: Fortuna Sittard - NEC Nijmegen
# Match 25 - Game 3: NAC Breda - Sparta Rotterdam
# Match 25 - Game 4: Almere City - Feyenoord
# Match 25 - Game 5: Ajax - FC Twente
# Match 25 - Game 6: FC Groningen - SC Heerenveen
# Match 25 - Game 7: PEC Zwolle - Go Ahead Eagles
# Match 25 - Game 8: FC Utrecht - Willem II
# Match 25 - Game 9: PSV - Heracles Almelo
# Moved to Match: 26
# There are 2 games in this match
# Match 26 - Game 1: SC Heerenveen - Feyenoord
# Match 26 - Game 2: Willem II - Go Ahead Eagles
# Moved to Match: 27
# There are 9 games in this match
# Match 27 - Game 1: Willem II - Ajax
# Match 27 - Game 2: Feyenoord - RKC Waalwijk
# Match 27 - Game 3: AZ - PEC Zwolle
# Match 27 - Game 4: SC Heerenveen - NAC Breda
# Match 27 - Game 5: Almere City - FC Groningen
# Match 27 - Game 6: Sparta Rotterdam - PSV
# Match 27 - Game 7: FC Twente - Fortuna Sittard
# Match 27 - Game 8: NEC Nijmegen - FC Utrecht
# Match 27 - Game 9: Go Ahead Eagles - Heracles Almelo
# Moved to Match: 28
# There are 9 games in this match
# Match 28 - Game 1: RKC Waalwijk - Almere City
# Match 28 - Game 2: NEC Nijmegen - AZ
# Match 28 - Game 3: FC Utrecht - Sparta Rotterdam
# Match 28 - Game 4: PSV - Feyenoord
# Match 28 - Game 5: PEC Zwolle - FC Twente
# Match 28 - Game 6: Ajax - SC Heerenveen
# Match 28 - Game 7: Fortuna Sittard - Go Ahead Eagles
# Match 28 - Game 8: NAC Breda - FC Groningen
# Match 28 - Game 9: Heracles Almelo - Willem II
# Moved to Match: 29
# There are 9 games in this match
# Match 29 - Game 1: Go Ahead Eagles - Ajax
# Match 29 - Game 2: Sparta Rotterdam - NEC Nijmegen
# Match 29 - Game 3: FC Groningen - RKC Waalwijk
# Match 29 - Game 4: Almere City - PEC Zwolle
# Match 29 - Game 5: Willem II - NAC Breda
# Match 29 - Game 6: FC Twente - PSV
# Match 29 - Game 7: AZ - Fortuna Sittard
# Match 29 - Game 8: Feyenoord - FC Utrecht
# Match 29 - Game 9: SC Heerenveen - Heracles Almelo
# Moved to Match: 30
# There are 9 games in this match
# Match 30 - Game 1: AZ - Almere City
# Match 30 - Game 2: RKC Waalwijk - Ajax
# Match 30 - Game 3: Fortuna Sittard - Sparta Rotterdam
# Match 30 - Game 4: NEC Nijmegen - Feyenoord
# Match 30 - Game 5: FC Utrecht - FC Twente
# Match 30 - Game 6: Heracles Almelo - PEC Zwolle
# Match 30 - Game 7: Willem II - SC Heerenveen
# Match 30 - Game 8: NAC Breda - Go Ahead Eagles
# Match 30 - Game 9: PSV - FC Groningen
# Moved to Match: 31
# There are 9 games in this match
# Match 31 - Game 1: Sparta Rotterdam - AZ
# Match 31 - Game 2: FC Groningen - NEC Nijmegen
# Match 31 - Game 3: SC Heerenveen - RKC Waalwijk
# Match 31 - Game 4: FC Twente - NAC Breda
# Match 31 - Game 5: Ajax - PSV
# Match 31 - Game 6: Almere City - Fortuna Sittard
# Match 31 - Game 7: Go Ahead Eagles - FC Utrecht
# Match 31 - Game 8: PEC Zwolle - Willem II
# Match 31 - Game 9: Feyenoord - Heracles Almelo
# Moved to Match: 32
# There are 9 games in this match
# Match 32 - Game 1: NEC Nijmegen - Almere City
# Match 32 - Game 2: Heracles Almelo - Ajax
# Match 32 - Game 3: Willem II - Feyenoord
# Match 32 - Game 4: FC Twente - AZ
# Match 32 - Game 5: NAC Breda - PEC Zwolle
# Match 32 - Game 6: Fortuna Sittard - SC Heerenveen
# Match 32 - Game 7: Sparta Rotterdam - Go Ahead Eagles
# Match 32 - Game 8: FC Utrecht - FC Groningen
# Match 32 - Game 9: PSV - RKC Waalwijk
# Moved to Match: 33
# There are 9 games in this match
# Match 33 - Game 1: FC Twente - Almere City
# Match 33 - Game 2: Feyenoord - AZ
# Match 33 - Game 3: Go Ahead Eagles - NEC Nijmegen
# Match 33 - Game 4: PEC Zwolle - Sparta Rotterdam
# Match 33 - Game 5: Heracles Almelo - NAC Breda
# Match 33 - Game 6: SC Heerenveen - PSV
# Match 33 - Game 7: FC Groningen - Fortuna Sittard
# Match 33 - Game 8: Ajax - FC Utrecht
# Match 33 - Game 9: RKC Waalwijk - Willem II
# Moved to Match: 34
# There are 9 games in this match
# Match 34 - Game 1: AZ - Ajax
# Match 34 - Game 2: PEC Zwolle - RKC Waalwijk
# Match 34 - Game 3: Go Ahead Eagles - Feyenoord
# Match 34 - Game 4: FC Twente - SC Heerenveen
# Match 34 - Game 5: Almere City - NAC Breda
# Match 34 - Game 6: Sparta Rotterdam - FC Groningen
# Match 34 - Game 7: FC Utrecht - PSV
# Match 34 - Game 8: Fortuna Sittard - Willem II
# Match 34 - Game 9: NEC Nijmegen - Heracles Almelo
# Moved to Match: 35
# There are 9 games in this match
# Match 35 - Game 1: SC Heerenveen - Almere City
# Match 35 - Game 2: Heracles Almelo - AZ
# Match 35 - Game 3: Willem II - NEC Nijmegen
# Match 35 - Game 4: Ajax - Sparta Rotterdam
# Match 35 - Game 5: Feyenoord - FC Twente
# Match 35 - Game 6: FC Groningen - PEC Zwolle
# Match 35 - Game 7: PSV - Go Ahead Eagles
# Match 35 - Game 8: NAC Breda - Fortuna Sittard
# Match 35 - Game 9: FC Utrecht - RKC Waalwijk
# Moved to Match: 36
# There are 9 games in this match
# Match 36 - Game 1: Fortuna Sittard - Ajax
# Match 36 - Game 2: FC Twente - RKC Waalwijk
# Match 36 - Game 3: AZ - SC Heerenveen
# Match 36 - Game 4: NEC Nijmegen - NAC Breda
# Match 36 - Game 5: Feyenoord - FC Groningen
# Match 36 - Game 6: Almere City - PSV
# Match 36 - Game 7: PEC Zwolle - FC Utrecht
# Match 36 - Game 8: Go Ahead Eagles - Willem II
# Match 36 - Game 9: Sparta Rotterdam - Heracles Almelo
# Moved to Match: 37
# There are 9 games in this match
# Match 37 - Game 1: Heracles Almelo - Almere City
# Match 37 - Game 2: NAC Breda - AZ
# Match 37 - Game 3: RKC Waalwijk - NEC Nijmegen
# Match 37 - Game 4: Willem II - Sparta Rotterdam
# Match 37 - Game 5: Ajax - Feyenoord
# Match 37 - Game 6: FC Groningen - FC Twente
# Match 37 - Game 7: PSV - PEC Zwolle
# Match 37 - Game 8: SC Heerenveen - Go Ahead Eagles
# Match 37 - Game 9: FC Utrecht - Fortuna Sittard
# Moved to Match: 38
# There are 1 games in this match
# Match 38 - Game 1: SC Heerenveen - Go Ahead Eagles
# Moved to Match: 39

# %%
df
# Out:
#      Match Game           Team Home_or_Away              Name Rating
# 0        1    1   FC Groningen         Away        Verbruggen      5
# 1        1    1   FC Groningen         Away         Benedetti      7
# 2        1    1   FC Groningen         Away  Gabriel Paulista      6
# 3        1    1   FC Groningen         Away             Thiaw      6
# 4        1    1   FC Groningen         Away             Dedic      5
# ...    ...  ...            ...          ...               ...    ...
# 7569    38    1  SC Heerenveen         Home         Fernandes      6
# 7570    38    1  SC Heerenveen         Home   Vinicius Junior      6
# 7571    38    1  SC Heerenveen         Home          Gyökeres      6
# 7572    38    1  SC Heerenveen         Home             Sávio      6
# 7573    38    1  SC Heerenveen         Home           Al-Saed      6
#
# [7574 rows x 6 columns]

# %%
df.to_csv("D:\Webscraping\player_rating.csv", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\hoybr\AppData\Local\Temp\ipykernel_32800\4220867284.py:1: SyntaxWarning: invalid escape sequence '\W'
#   df.to_csv("D:\Webscraping\player_rating.csv", index=False)

# %% [markdown]
# ## Collecting match events

# %%
def extract_events(driver):
    events = []
    for half in ["First", "Second"]:
        table = driver.find_element(By.XPATH, f"//table[contains(@class, 'table-match-events')][.//th[contains(text(), '{half} half')]]")
        rows = table.find_elements(By.TAG_NAME, "tr")[1:]  # Skip header row
        
        for row in rows:
            minute = row.find_element(By.XPATH, ".//td[contains(@class, 'td-event-home-minute')]/span").text
            
            for side in ['home', 'away']:
                try:
                    name_cell = row.find_element(By.XPATH, f".//td[contains(@class, 'td-event-{side}-names')]")
                    icon_cell = row.find_element(By.XPATH, f".//td[contains(@class, 'td-event-{side}-icon')]")
                    
                    player_name = name_cell.find_element(By.XPATH, ".//div[@class='semi-bold']").text
                    
                    if "icon-matchevent-goal" in icon_cell.get_attribute("innerHTML"):
                        assist = name_cell.find_elements(By.XPATH, ".//div[contains(text(), 'Assist:')]")
                        assist = assist[0].text.replace("Assist: ", "") if assist else None
                        events.append({"Half": half, "Minute": minute, "Event": "Goal", "Player": player_name, "Assist": assist, "Team": side.capitalize()})
                    
                    if "icon-player-yellowcard" in icon_cell.get_attribute("innerHTML"):
                        reason = name_cell.find_elements(By.XPATH, ".//div[not(@class)]")
                        reason = reason[0].text if reason else None
                        events.append({"Half": half, "Minute": minute, "Event": "Yellow Card", "Player": player_name, "Reason": reason, "Team": side.capitalize()})
                    
                    if "icon-player-redcard" in icon_cell.get_attribute("innerHTML"):
                        reason = name_cell.find_elements(By.XPATH, ".//div[not(@class)]")
                        reason = reason[0].text if reason else None
                        events.append({"Half": half, "Minute": minute, "Event": "Red Card", "Player": player_name, "Reason": reason,"Team": side.capitalize()})
                        

                    if "Missed penalty" in name_cell.text:
                        events.append({"Half": half, "Minute": minute, "Event": "Missed Penalty", "Player": player_name, "Team": side.capitalize()})
                
                        
                except Exception as e:
                    pass  # No event for this side in this row
    
    return events

# %%
# Wait for the table to load
wait = WebDriverWait(driver, 10)
wait.until(EC.presence_of_element_located((By.CLASS_NAME, "table-match-events")))

# Call the extract_events function
all_events = extract_events(driver)

# Create a DataFrame from the extracted events
df = pd.DataFrame(all_events)

# %%
df
# Out:
#      Half Minute        Event            Player        Assist  Team  \
# 0  Second     46         Goal       12. Jönsson        Provod  Away
# 1  Second     48         Goal      7. Arokodare   T. Martínez  Away
# 2  Second     49     Red Card     15. Hernández           NaN  Home
# 3  Second     51  Yellow Card    7. L. Martínez           NaN  Home
# 4  Second     66         Goal         4. Provod       Godfrey  Away
# 5  Second     72  Yellow Card      7. Arokodare           NaN  Away
# 6  Second     77         Goal  11. Tete Morente       Jönsson  Away
# 7  Second     80         Goal  11. Tete Morente       Godfrey  Away
# 8  Second     88         Goal          14. Guth  Tete Morente  Away
# 9  Second     90         Goal      7. Arokodare         Longo  Away
#
#                                               Reason
# 0                                                NaN
# 1                                                NaN
# 2                 15. Hernández\nHitting an opponent
# 3  7. L. Martínez\nDenying an obvious goal-scorin...
# 4                                                NaN
# 5  7. Arokodare\nAsking for a yellow card for an ...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
# Empty list to store match events data
match_events = []

# Scraping the table containing the match events
events_table = driver.find_elements(By.CSS_SELECTOR, "table.table-match-events tbody tr")

# Loop through the rows in the table
for row in events_table:
    # Minute of the event
    minute = row.find_element(By.CSS_SELECTOR, "td.td-event-home-minute span").text
    
    # Home team events (goals, yellow/red cards, substitutions, etc.)
    home_event = row.find_element(By.CSS_SELECTOR, "td.td-event-home-event div").get_attribute('title') if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-event div") else None
    home_player = row.find_element(By.CSS_SELECTOR, "td.td-event-home-names div.semi-bold").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-names div.semi-bold") else None
    home_action = row.find_element(By.CSS_SELECTOR, "td.td-event-home-names div.semi-bold + div").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-names div.semi-bold + div") else None
    home_score = row.find_element(By.CSS_SELECTOR, "td.td-event-home-score span").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-score span") else None
    
    # Away team events (goals, yellow/red cards, substitutions, etc.)
    away_event = row.find_element(By.CSS_SELECTOR, "td.td-event-away-event div").get_attribute('title') if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-event div") else None
    away_player = row.find_element(By.CSS_SELECTOR, "td.td-event-away-names div.semi-bold").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-names div.semi-bold") else None
    away_action = row.find_element(By.CSS_SELECTOR, "td.td-event-away-names div.semi-bold + div").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-names div.semi-bold + div") else None
    away_score = row.find_element(By.CSS_SELECTOR, "td.td-event-away-score span").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-score span") else None
    

    homeEvent = row.find_element(By.CSS_SELECTOR, "td.td-event-home-icon span").get_attribute("class") if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-icon span") else None
    awayEvent = row.find_element(By.CSS_SELECTOR, "td.td-event-away-icon span").get_attribute("class") if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-icon span") else None

    # Add the event details to the match_events list as a dictionary
    match_events.append({
        'Minute': minute,
        'Home Player': home_player,
        'Home Action': home_action,
        'Home Score': home_score,
        'Away Player': away_player,
        'Away Action': away_action,
        'Away Score': away_score,
        'Home Event': homeEvent,
        'Away Event': awayEvent
    })

# %%
# Create a pandas DataFrame from the match_events list
df = pd.DataFrame(match_events)

# Display the DataFrame
df
# Out:
#    Minute    Home Player         Home Action Home Score   Away Player  \
# 0      10       11. Leão     Assist: Ronaldo        1-0          None
# 1      18  9. Kulusevski      Assist: Romero        2-0          None
# 2      26         3. Aké  Assist: Kulusevski        3-0          None
# 3      33  9. Kulusevski      Assist: Romero        4-0          None
# 4      36           None                None       None   44. Noppert
# 5      54           None                None       None  8. Fernandes
# 6      66           None                None       None  48. Brouwers
# 7      73         3. Aké      Assist: Romero        5-0          None
# 8      74       11. Leão        Assist: Gavi        6-0          None
# 9      76           None                None       None  9. Karlsbakk
# 10     83     25. Soucek        Assist: Leão        7-0          None
#
#                            Away Action Away Score            Home Event  \
# 0                                 None       None  icon-matchevent-goal
# 1                                 None       None  icon-matchevent-goal
# 2                                 None       None  icon-matchevent-goal
# 3                                 None       None  icon-matchevent-goal
# 4   Involved in a quarrel on the pitch       None                  None
# 5     Making multiple deliberate fouls       None                  None
# 6                            Fernandes       None                  None
# 7                                 None       None  icon-matchevent-goal
# 8                                 None       None  icon-matchevent-goal
# 9                  10. Vinicius Junior       None                  None
# 10                                None       None  icon-matchevent-goal
#
#                 Away Event
# 0                     None
# 1                     None
# 2                     None
# 3                     None
# 4   icon-player-yellowcard
# 5   icon-player-yellowcard
# 6      icon-matchevent-sub
# 7                     None
# 8                     None
# 9      icon-matchevent-sub
# 10                    None

# %%
# Initialising dataframe
df = pd.DataFrame()

# %%
# Building a loop to collect match data in first page

# Loop through each game
for i in range(38, 40):

    time.sleep(3)

    # Find all <tr> elements with the class 'clickable'
    clickable_rows = driver.find_elements(By.XPATH, "//tr[contains(@class, 'clickable')]")

    # Count the number of elements
    clickable_count = len(clickable_rows)

    print(f'There are {clickable_count} games in this match')
    
    for j in range(1, clickable_count + 1):  # Assuming there are 9 games
        try:
            # Locate the game element using XPath
            game = wait.until(EC.element_to_be_clickable((By.XPATH, f'(//tr[contains(@class, "clickable")])[{j}]')))
            game.click()

            match_events = []


            # Wait for 6 seconds
            time.sleep(4)

            # Extract home and away team names
            homeTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[1]/div/div[2]/div').text
            awayTeam = driver.find_element(By.XPATH, '//*[@id="match-details"]/div/div[3]/div/div[2]/div').text


            # Scraping the table containing the match events
            events_table = driver.find_elements(By.CSS_SELECTOR, "table.table-match-events tbody tr")

            # Loop through the rows in the table
            for row in events_table:
                # Minute of the event
                minute = row.find_element(By.CSS_SELECTOR, "td.td-event-home-minute span").text
                
                # Home team events (goals, yellow/red cards, substitutions, etc.)
                home_event = row.find_element(By.CSS_SELECTOR, "td.td-event-home-event div").get_attribute('title') if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-event div") else None
                home_player = row.find_element(By.CSS_SELECTOR, "td.td-event-home-names div.semi-bold").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-names div.semi-bold") else None
                home_action = row.find_element(By.CSS_SELECTOR, "td.td-event-home-names div.semi-bold + div").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-names div.semi-bold + div") else None
                home_score = row.find_element(By.CSS_SELECTOR, "td.td-event-home-score span").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-score span") else None
                
                # Away team events (goals, yellow/red cards, substitutions, etc.)
                away_event = row.find_element(By.CSS_SELECTOR, "td.td-event-away-event div").get_attribute('title') if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-event div") else None
                away_player = row.find_element(By.CSS_SELECTOR, "td.td-event-away-names div.semi-bold").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-names div.semi-bold") else None
                away_action = row.find_element(By.CSS_SELECTOR, "td.td-event-away-names div.semi-bold + div").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-names div.semi-bold + div") else None
                away_score = row.find_element(By.CSS_SELECTOR, "td.td-event-away-score span").text if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-score span") else None
                

                homeEvent = row.find_element(By.CSS_SELECTOR, "td.td-event-home-icon span").get_attribute("class") if row.find_elements(By.CSS_SELECTOR, "td.td-event-home-icon span") else None
                awayEvent = row.find_element(By.CSS_SELECTOR, "td.td-event-away-icon span").get_attribute("class") if row.find_elements(By.CSS_SELECTOR, "td.td-event-away-icon span") else None

                # Add the event details to the match_events list as a dictionary
                match_events.append({
                    'Match': i,
                    'Game': j, 
                    'Minute': minute,
                    'Home Team': homeTeam,
                    'Away Team': awayTeam,
                    'Home Player': home_player,
                    'Home Action': home_action,
                    'Home Score': home_score,
                    'Away Player': away_player,
                    'Away Action': away_action,
                    'Away Score': away_score,
                    'Home Event': homeEvent,
                    'Away Event': awayEvent
                })

        

            # Create a DataFrame
            df_event = pd.DataFrame(match_events)

            # Adding to dataframe
            df = pd.concat([df, df_event], ignore_index=True)

            
            # Displaying the progress
            print(f"Match {i} - Game {j}: {homeTeam} - {awayTeam}")
            
            
            # Wait for 2.5 seconds
            time.sleep(1.5)
            
            # Locate and click the exit element (the close button with the 'x' icon)
            exit_button = wait.until(EC.element_to_be_clickable((By.XPATH, '//span[@class="fa fa-times"]')))
            exit_button.click()
            
            # Wait for any transition effects
            time.sleep(2)
            
        except Exception as e:
            print(f"An error occurred on Match {i}, Game {j}: {e}")



    try:
        matchPage = wait.until(EC.element_to_be_clickable((By.XPATH, '//div[contains(@class, "button-arrow3-right")]')))
        matchPage.click()
        print(f'Moved to Match: {i + 1}')
        time.sleep(1.5)
    except Exception as e:
        print(f"Error moving to next match page: {e}")
        break  # Exit the loop if we can't move to the next page
# Out:
# There are 1 games in this match
# Match 38 - Game 1: SC Heerenveen - Go Ahead Eagles
# Moved to Match: 39
# There are 9 games in this match
# Match 39 - Game 1: Almere City - Ajax
# Match 39 - Game 2: Sparta Rotterdam - RKC Waalwijk
# Match 39 - Game 3: PEC Zwolle - SC Heerenveen
# Match 39 - Game 4: Feyenoord - NAC Breda
# Match 39 - Game 5: Go Ahead Eagles - FC Groningen
# Match 39 - Game 6: NEC Nijmegen - PSV
# Match 39 - Game 7: AZ - FC Utrecht
# Match 39 - Game 8: FC Twente - Willem II
# Match 39 - Game 9: Fortuna Sittard - Heracles Almelo
# Error moving to next match page: Message:

# %%
df
# Out:
#       Match  Game Minute        Home Team        Away Team   Home Player  \
# 0         1     1      7             Ajax     FC Groningen   7. Bergwijn
# 1         1     1      9             Ajax     FC Groningen    2. Sánchez
# 2         1     1     39             Ajax     FC Groningen  23. Berghuis
# 3         1     1     50             Ajax     FC Groningen          None
# 4         1     1     54             Ajax     FC Groningen          None
# ...     ...   ...    ...              ...              ...           ...
# 2375     39     9     56  Fortuna Sittard  Heracles Almelo          None
# 2376     39     9     66  Fortuna Sittard  Heracles Almelo   16. Rongier
# 2377     39     9     76  Fortuna Sittard  Heracles Almelo          None
# 2378     39     9     87  Fortuna Sittard  Heracles Almelo    15. Otávio
# 2379     39     9     91  Fortuna Sittard  Heracles Almelo          None
#
#                                    Home Action Home Score       Away Player  \
# 0                              Assist: Brobbey        1-0              None
# 1     Asking for a yellow card for an opponent       None              None
# 2                            Assist: Longstaff        2-0              None
# 3                                         None       None          3. Dedic
# 4                                         None       None        19. Ângelo
# ...                                        ...        ...               ...
# 2375                                      None       None         10. Wirtz
# 2376                            Assist: Otávio        1-1              None
# 2377                                      None       None         8. Yüksek
# 2378                         Assist: Aebischer        2-1              None
# 2379                                      None       None  30. van Oorschot
#
#                                             Away Action Away Score  \
# 0                                                  None       None
# 1                                                  None       None
# 2                                                  None       None
# 3                                                Diving       None
# 4                                     Assist: Benedetti        2-1
# ...                                                 ...        ...
# 2375  Attempting to kick the ball in a dangerous manner       None
# 2376                                               None       None
# 2377                                       17. T. Bruns       None
# 2378                                               None       None
# 2379                                     Assist: Thuram        2-2
#
#                   Home Event              Away Event
# 0       icon-matchevent-goal                    None
# 1     icon-player-yellowcard                    None
# 2       icon-matchevent-goal                    None
# 3                       None  icon-player-yellowcard
# 4                       None    icon-matchevent-goal
# ...                      ...                     ...
# 2375                    None  icon-player-yellowcard
# 2376    icon-matchevent-goal                    None
# 2377                    None     icon-matchevent-sub
# 2378    icon-matchevent-goal                    None
# 2379                    None    icon-matchevent-goal
#
# [2380 rows x 13 columns]

# %%
# Exporting the data
df.to_csv("D:\Webscraping\match_event.csv", index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\hoybr\AppData\Local\Temp\ipykernel_27780\2375229036.py:2: SyntaxWarning: invalid escape sequence '\W'
#   df.to_csv("D:\Webscraping\match_event.csv", index=False)

# %% [markdown]
# ## Collecting referee and player of the match

# %%
try:
    # Wait for and locate the referee details div
    referee_div = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, "match-details-referee"))
    )

    # Extract Referee Name
    referee_name = referee_div.find_element(By.CSS_SELECTOR, "span[data-bind='text: name']").text

    # Determine Referee Strictness
    strictness_element = referee_div.find_element(By.CSS_SELECTOR, "span.icon-referee")
    strictness_class = strictness_element.get_attribute("class")

    if "verystrict" in strictness_class:
        strictness = "Very Strict"
    elif "strict" in strictness_class:
        strictness = "Strict"
    elif "lenient" in strictness_class:
        strictness = "Lenient"
    elif "verylenient" in strictness_class:
        strictness = "Very Lenient"
    else:
        strictness = "Average"

    # Extract Man of the Match (assuming this part remains the same)
    man_of_match_element = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CSS_SELECTOR, "#table-man-of-the-match .semi-bold"))
    )
    man_of_match = man_of_match_element.text

    # Print the results
    print(f"Man of the Match: {man_of_match}")
    print(f"Referee: {referee_name}")
    print(f"Referee Strictness: {strictness}")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Man of the Match: 7. A. Pérez
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict

# %%
df = pd.DataFrame()

# %%
transfers = []

try:
    # Wait for the table to be present
    table = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, '//*[@id="transfer-history"]/div/table'))
    )

    # Find all rows in the table body
    rows = table.find_elements(By.XPATH, ".//tbody/tr")

    for i, row in enumerate(rows, start=1):
        try:
            transfer_data = {
                "Player": safe_find(row, ".//td[1]//span[contains(@data-bind, 'player.name')]"),
                "From": safe_find(row, ".//td[2]//div/div[1]/a") or safe_find(row, ".//td[2]//div/div[1]/span"),
                "To": safe_find(row, ".//td[3]/div/div[1]/a") or safe_find(row, ".//td[3]/div/div[1]/span"),
                "Position": safe_find(row, ".//td[4]"),
                "Week": safe_find(row, ".//td[5]"),
                "Value": safe_find(row, ".//td[6]//span[@class='club-funds-amount']"),
                "Price": safe_find(row, ".//td[7]//span[@class='club-funds-amount']"),
                "Date": safe_find(row, ".//td[8]")
            }
            transfers.append(transfer_data)

        except Exception as e:
            print(f"Error processing row {i}: {e}")

    # Create DataFrame
    df = pd.DataFrame(transfers)

    # Display the first few rows of the DataFrame
    print(df.head())

    # Optional: Save to CSV
    # df.to_csv("transfers.csv", index=False)

except TimeoutException:
    print("Timed out waiting for the table to load")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# There are 9 games in this match
# Man of the Match: 7. Bergwijn
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 71. Proper
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 7. L. Martínez
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 29. Rached
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 7. A. Pérez
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 7. Osimhen
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 15. Gregoritsch
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 9. Höler
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 17. T. Bruns
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Moved to Match: 2
# There are 9 games in this match
# Man of the Match: 17. Sávio
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 9. Höler
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 9. Kulusevski
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 11. Tete Morente
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 15. Boufal
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 17. Sané
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 8. Puig
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 8. Al-Musrati
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 23. Veerman
# Referee: Erwin Blank
# Referee Strictness: Average
# Moved to Match: 3
# There are 9 games in this match
# Man of the Match: 11. Bakayoko
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 10. Perisic
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 11. Lewandowski
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 14. Rodri
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 21. Koopmeiners
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 11. Leão
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 9. T. Martínez
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 17. Sahiti
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 17. Sávio
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Moved to Match: 4
# There are 2 games in this match
# Man of the Match: 9. Furuhashi
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 8. Gharbi
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Moved to Match: 5
# There are 9 games in this match
# Man of the Match: 11. Leão
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 9. Kane
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 9. Batshuayi
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 7. Højlund
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 9. T. Martínez
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 16. Soler
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 11. J. Clarke
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 11. Bakayoko
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 17. Sávio
# Referee: Rob Dieperink
# Referee Strictness: Average
# Moved to Match: 6
# There are 9 games in this match
# Man of the Match: 9. Jackson
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 12. González
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 11. Kolo Muani
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 17. Bellingham
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 8. Longstaff
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 7. Raphinha
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 16. Fernandes
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 9. Lukaku
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 7. Osimhen
# Referee: Erwin Blank
# Referee Strictness: Average
# Moved to Match: 7
# There are 9 games in this match
# Man of the Match: 9. Lukaku
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 5. Magalhães
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 7. van Bommel
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 10. Vinicius Junior
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 7. Foden
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 7. Osimhen
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 23. Sadílek
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 17. Sávio
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 9. Kulusevski
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Moved to Match: 8
# There are 9 games in this match
# Man of the Match: 9. Furuhashi
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 8. Barella
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 15. Gregoritsch
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 11. Bakayoko
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 15. Boufal
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 7. O. Dembélé
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 11. Leão
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 11. Kolo Muani
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 9. Benzema
# Referee: Kevin Blom
# Referee Strictness: Strict
# Moved to Match: 9
# There are 9 games in this match
# Man of the Match: 10. Pedri
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 8. Barella
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 9. Icardi
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 17. Fontana
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 15. Sané
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 11. Bakayoko
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 12. Griezmann
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 17. Sávio
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 7. O. Dembélé
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Moved to Match: 10
# There are 9 games in this match
# Man of the Match: 8. Resink
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 20. Soucek
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 8. Partey
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 17. Bellingham
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 9. Toney
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 7. Núñez
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 9. Benzema
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 10. Pedri
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 10. Valverde
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Moved to Match: 11
# There are 9 games in this match
# Man of the Match: 7. van Bommel
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 23. Sano
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 10. Vinicius Junior
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 11. Kolo Muani
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 22. Watkins
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 4. Provod
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 11. Leão
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 11. Neymar
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 14. Rodri
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Moved to Match: 12
# There are 8 games in this match
# Man of the Match: 15. Sané
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 19. Saka
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 7. Rodrygo
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 9. Toney
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 17. Bellingham
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 7. Osimhen
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 10. Vinicius Junior
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 12. González
# Referee: Richard Martens
# Referee Strictness: Strict
# Moved to Match: 13
# There are 9 games in this match
# Man of the Match: 8. Jones
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 17. Messi
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 11. Neymar
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 15. Díaz
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 8. Fabinho
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 6. Caicedo
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 7. Rodrygo
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 12. Vitinha
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 9. de Jong
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Moved to Match: 14
# There are 9 games in this match
# Man of the Match: 7. Højlund
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 17. Bellingham
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 9. Kulusevski
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 10. Gallagher
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 11. Kolo Muani
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 10. Vinicius Junior
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 15. Lucas Moura
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 22. Watkins
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 7. Doodeman
# Referee: Siemen Mulder
# Referee Strictness: Average
# Moved to Match: 15
# There are 9 games in this match
# Man of the Match: 22. Watkins
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 14. Vellios
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 10. Pedri
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 6. Caicedo
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 3. Kumbedi
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 7. Foden
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 27. Lozano
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 15. Sané
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 17. Loftus-Cheek
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Moved to Match: 16
# There are 9 games in this match
# Man of the Match: 7. Lamine Yamal
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 9. Batshuayi
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 7. T. Müller
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 11. Gakpo
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 10. Rice
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 7. Foden
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 9. Kulusevski
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 11. Kolo Muani
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 11. Gabriel Jesus
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Moved to Match: 17
# There are 9 games in this match
# Man of the Match: 3. de Ligt
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 19. Rashford
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 7. Lamine Yamal
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 16. Szoboszlai
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 9. Zirkzee
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 11. Bakayoko
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 11. Gabriel Jesus
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 10. Pedri
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 9. Batshuayi
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Moved to Match: 18
# There are 9 games in this match
# Man of the Match: 10. Wirtz
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 29. Rached
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 10. S. Hansen
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 11. Neymar
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 17. Raphinha
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 11. Salah
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 11. Bakayoko
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 9. Kulusevski
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 10. Havertz
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Moved to Match: 19
# There are 4 games in this match
# Man of the Match: 4. de Paul
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 10. Pedri
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 18. Camavinga
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 8. Fernandes
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Moved to Match: 20
# There are 9 games in this match
# Man of the Match: 17. Raphinha
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 13. J. Baas
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 10. Vinicius Junior
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 14. Elmalı
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 11. Leão
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 7. T. Müller
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 9. Son Heung-min
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 9. Benzema
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 16. Rongier
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Moved to Match: 21
# There are 9 games in this match
# Man of the Match: 11. Kvaratskhelia
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 11. Stuani
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 19. Mbappé
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 29. Rached
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 9. Kulusevski
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 11. Bakayoko
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 10. Vinicius Junior
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 9. Benzema
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 7. Núñez
# Referee: Kevin Blom
# Referee Strictness: Strict
# Moved to Match: 22
# There are 9 games in this match
# Man of the Match: 7. Coman
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 15. Messi
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 10. Pedri
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 4. Provod
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 19. Rashford
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 17. Raphinha
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 7. Lamine Yamal
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 7. Foden
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 29. Rached
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Moved to Match: 23
# There are 9 games in this match
# Man of the Match: 10. Valverde
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 14. Eze
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 7. Guillaume
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 7. L. Martínez
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 7. Bowen
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 9. Kulusevski
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 7. Hwang Hee-chan
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 4. Puig
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 7. Coman
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Moved to Match: 24
# There are 9 games in this match
# Man of the Match: 31. Lamine Yamal
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 18. N. Williams
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 17. T. Bruns
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 7. Højlund
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 16. Rongier
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 7. Sávio
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 14. Isak
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 16. Barella
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 17. Sané
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Moved to Match: 25
# There are 9 games in this match
# Man of the Match: 2. Sugawara
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 14. Eze
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 9. H. Araújo
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 18. Camavinga
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 7. Bowen
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 7. Sávio
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 19. Gavi
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 11. Neymar
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 5. Gvardiol
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Moved to Match: 26
# There are 2 games in this match
# Man of the Match: 13. Gyökeres
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 19. Gavi
# Referee: Richard Martens
# Referee Strictness: Strict
# Moved to Match: 27
# There are 9 games in this match
# Man of the Match: 11. Perisic
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 9. Furuhashi
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 7. van Bommel
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 6. Caicedo
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 4. Maddison
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 10. Valverde
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 12. Griezmann
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 7. J. Álvarez
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 11. Leão
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Moved to Match: 28
# There are 9 games in this match
# Man of the Match: 23. Balboa
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 12. González
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 19. Jorginho
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 13. Lucas Paquetá
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 19. Rashford
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 13. Gyökeres
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 9. Kulusevski
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 9. O. Dembélé
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 9. Benzema
# Referee: Siemen Mulder
# Referee Strictness: Average
# Moved to Match: 29
# There are 9 games in this match
# Man of the Match: 31. Lamine Yamal
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 23. Sano
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 4. Maddison
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 18. Velanas
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 9. Benzema
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 19. Rashford
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 9. T. Martínez
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 11. Gabriel Jesus
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 33. Kudus
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Moved to Match: 30
# There are 9 games in this match
# Man of the Match: 7. van Bommel
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 17. Raphinha
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 4. Provod
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 7. J. Álvarez
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 7. Højlund
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 11. Thuram
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 7. Sávio
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 11. Leão
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 14. Isak
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Moved to Match: 31
# There are 9 games in this match
# Man of the Match: 10. Gallagher
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 23. Sano
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 6. Caicedo
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 19. Rashford
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 7. Bowen
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 5. de Vrij
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 11. Leão
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 9. Benzema
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 18. Camavinga
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Moved to Match: 32
# There are 9 games in this match
# Man of the Match: 9. T. Müller
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 19. Oyarzabal
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 2. Dias
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 7. van Bommel
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 4. Wagner
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 13. Gyökeres
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 9. Kulusevski
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 14. Isak
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 10. Valverde
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Moved to Match: 33
# There are 9 games in this match
# Man of the Match: 4. Youssouf Fofana
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 19. Mbappé
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 11. Leão
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 10. Gallagher
# Referee: Richard Martens
# Referee Strictness: Strict
# Man of the Match: 7. Núñez
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 7. Sávio
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 4. Provod
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 9. Vlahović
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 16. Barella
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Moved to Match: 34
# There are 9 games in this match
# Man of the Match: 7. Bowen
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 14. Vellios
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 11. Leão
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Man of the Match: 13. Gyökeres
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Man of the Match: 29. Rached
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 18. Fernández
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 11. Bakayoko
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 8. Kudus
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 16. Szoboszlai
# Referee: Kevin Blom
# Referee Strictness: Strict
# Moved to Match: 35
# There are 9 games in this match
# Man of the Match: 10. Vinicius Junior
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 4. Palmer
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 7. Berisha
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 7. Bowen
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 2. Davies
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 18. Fernández
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 7. Lamine Yamal
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 7. Hwang Hee-chan
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 15. van Dijk
# Referee: Sander van der Eijk
# Referee Strictness: Lenient
# Moved to Match: 36
# There are 9 games in this match
# Man of the Match: 7. Bowen
# Referee: Rob Dieperink
# Referee Strictness: Average
# Man of the Match: 19. Rashford
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 6. Caicedo
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Man of the Match: 7. J. Álvarez
# Referee: Bas Nijhuis
# Referee Strictness: Lenient
# Man of the Match: 7. Foden
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 11. Bakayoko
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 17. Sané
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 9. Openda
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 10. Wirtz
# Referee: Edwin van de Graaf
# Referee Strictness: Strict
# Moved to Match: 37
# There are 9 games in this match
# Man of the Match: 7. Núñez
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 11. J. Clarke
# Referee: Jeroen Manschot
# Referee Strictness: Average
# Man of the Match: 7. J. Álvarez
# Referee: Dennis Higler
# Referee Strictness: Very Strict
# Man of the Match: 15. Messi
# Referee: Erwin Blank
# Referee Strictness: Average
# Man of the Match: 23. Kane
# Referee: Marc Nagtegaal
# Referee Strictness: Lenient
# Man of the Match: 14. Isak
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 20. Til
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Man of the Match: 7. Sávio
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 7. Hwang Hee-chan
# Referee: Jannick van der Laan
# Referee Strictness: Lenient
# Moved to Match: 38
# There are 1 games in this match
# Man of the Match: 8. Gavi
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Moved to Match: 39
# There are 9 games in this match
# Man of the Match: 11. Perisic
# Referee: Siemen Mulder
# Referee Strictness: Average
# Man of the Match: 7. Gnonto
# Referee: Martin van den Kerkhof
# Referee Strictness: Lenient
# Man of the Match: 13. Gyökeres
# Referee: Serdar Gözübüyük
# Referee Strictness: Very Strict
# Man of the Match: 9. H. Araújo
# Referee: Jochem Kamphuis
# Referee Strictness: Very Strict
# Man of the Match: 9. Openda
# Referee: Pol van Boekel
# Referee Strictness: Strict
# Man of the Match: 7. J. Álvarez
# Referee: Danny Makkelie
# Referee Strictness: Very Strict
# Man of the Match: 17. Sané
# Referee: Allard Lindhout
# Referee Strictness: Lenient
# Man of the Match: 15. Messi
# Referee: Kevin Blom
# Referee Strictness: Strict
# Man of the Match: 7. Núñez
# Referee: Laurens Gerrets
# Referee Strictness: Lenient
# Error moving to next match page: Message:

# %%
df
# Out:
#      Match  Game             Referee         Mood Player of the Match
# 0        1     1       Dennis Higler  Very Strict         7. Bergwijn
# 1        1     2  Edwin van de Graaf       Strict          71. Proper
# 2        1     3     Laurens Gerrets      Lenient      7. L. Martínez
# 3        1     4         Erwin Blank      Average          29. Rached
# 4        1     5     Jochem Kamphuis  Very Strict         7. A. Pérez
# ..     ...   ...                 ...          ...                 ...
# 318     39     5      Pol van Boekel       Strict           9. Openda
# 319     39     6      Danny Makkelie  Very Strict       7. J. Álvarez
# 320     39     7     Allard Lindhout      Lenient            17. Sané
# 321     39     8          Kevin Blom       Strict           15. Messi
# 322     39     9     Laurens Gerrets      Lenient            7. Núñez
#
# [323 rows x 5 columns]

# %%
# Exporting the data
df.to_csv("D:\Webscraping\player_referee.csv", index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\hoybr\AppData\Local\Temp\ipykernel_27780\81684928.py:2: SyntaxWarning: invalid escape sequence '\W'
#   df.to_csv("D:\Webscraping\player_referee.csv", index=False)

# %% [markdown]
# ## Collecting transfer data

# %%
def safe_find(element, xpaths):
    for xpath in xpaths:
        try:
            return element.find_element(By.XPATH, xpath).text
        except NoSuchElementException:
            continue
    return "N/A"

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
df = pd.DataFrame()

# %%
transfers = []
# MAX_TRANSFERS = 20

try:
    # Wait for the table to be present
    table = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, '//*[@id="transfer-history"]/div/table'))
    )

    # Find all rows in the table body
    rows = table.find_elements(By.XPATH, ".//tbody/tr")

    for i, row in enumerate(rows, start=1):
        # if i > MAX_TRANSFERS:
        #     break

        try:
            transfer_data = {
                "Player": safe_find(row, [".//td[1]//span[contains(@data-bind, 'player.name')]"]),
                "From": safe_find(row, [
                    ".//td[2]//div/div[1]/a",
                    ".//td[2]//div/div/span"
                ]),
                "To": safe_find(row, [
                    ".//td[3]/div/div[1]/a",
                    ".//td[3]/div/div/span"
                ]),
                "Position": safe_find(row, [".//td[4]"]),
                "Week": safe_find(row, [".//td[5]"]),
                "Value": safe_find(row, [".//td[6]//span[@class='club-funds-amount']"]),
                "Price": safe_find(row, [".//td[7]//span[@class='club-funds-amount']"]),
                "Date": safe_find(row, [".//td[8]"])
            }
            transfers.append(transfer_data)

            print(f"Processed transfer {i} of {len(rows)}")

        except Exception as e:
            print(f"Error processing row {i}: {e}")

    # Create DataFrame
    df = pd.DataFrame(transfers)

    # Display the DataFrame
    print(df)

    # Optional: Save to CSV
    # df.to_csv("transfers.csv", index=False)

except TimeoutException:
    print("Timed out waiting for the table to load")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Processed transfer 1 of 1486
# Processed transfer 2 of 1486
# Processed transfer 3 of 1486
# Processed transfer 4 of 1486
# Processed transfer 5 of 1486
# Processed transfer 6 of 1486
# Processed transfer 7 of 1486
# Processed transfer 8 of 1486
# Processed transfer 9 of 1486
# Processed transfer 10 of 1486
# Processed transfer 11 of 1486
# Processed transfer 12 of 1486
# Processed transfer 13 of 1486
# Processed transfer 14 of 1486
# Processed transfer 15 of 1486
# Processed transfer 16 of 1486
# Processed transfer 17 of 1486
# Processed transfer 18 of 1486
# Processed transfer 19 of 1486
# Processed transfer 20 of 1486
# Processed transfer 21 of 1486
# Processed transfer 22 of 1486
# Processed transfer 23 of 1486
# Processed transfer 24 of 1486
# Processed transfer 25 of 1486
# Processed transfer 26 of 1486
# Processed transfer 27 of 1486
# Processed transfer 28 of 1486
# Processed transfer 29 of 1486
# Processed transfer 30 of 1486
# Processed transfer 31 of 1486
# Processed transfer 32 of 1486
# Processed transfer 33 of 1486
# Processed transfer 34 of 1486
# Processed transfer 35 of 1486
# Processed transfer 36 of 1486
# Processed transfer 37 of 1486
# Processed transfer 38 of 1486
# Processed transfer 39 of 1486
# Processed transfer 40 of 1486
# Processed transfer 41 of 1486
# Processed transfer 42 of 1486
# Processed transfer 43 of 1486
# Processed transfer 44 of 1486
# Processed transfer 45 of 1486
# Processed transfer 46 of 1486
# Processed transfer 47 of 1486
# Processed transfer 48 of 1486
# Processed transfer 49 of 1486
# Processed transfer 50 of 1486
# Processed transfer 51 of 1486
# Processed transfer 52 of 1486
# Processed transfer 53 of 1486
# Processed transfer 54 of 1486
# Processed transfer 55 of 1486
# Processed transfer 56 of 1486
# Processed transfer 57 of 1486
# Processed transfer 58 of 1486
# Processed transfer 59 of 1486
# Processed transfer 60 of 1486
# Processed transfer 61 of 1486
# Processed transfer 62 of 1486
# Processed transfer 63 of 1486
# Processed transfer 64 of 1486
# Processed transfer 65 of 1486
# Processed transfer 66 of 1486
# Processed transfer 67 of 1486
# Processed transfer 68 of 1486
# Processed transfer 69 of 1486
# Processed transfer 70 of 1486
# Processed transfer 71 of 1486
# Processed transfer 72 of 1486
# Processed transfer 73 of 1486
# Processed transfer 74 of 1486
# Processed transfer 75 of 1486
# Processed transfer 76 of 1486
# Processed transfer 77 of 1486
# Processed transfer 78 of 1486
# Processed transfer 79 of 1486
# Processed transfer 80 of 1486
# Processed transfer 81 of 1486
# Processed transfer 82 of 1486
# Processed transfer 83 of 1486
# Processed transfer 84 of 1486
# Processed transfer 85 of 1486
# Processed transfer 86 of 1486
# Processed transfer 87 of 1486
# Processed transfer 88 of 1486
# Processed transfer 89 of 1486
# Processed transfer 90 of 1486
# Processed transfer 91 of 1486
# Processed transfer 92 of 1486
# Processed transfer 93 of 1486
# Processed transfer 94 of 1486
# Processed transfer 95 of 1486
# Processed transfer 96 of 1486
# Processed transfer 97 of 1486
# Processed transfer 98 of 1486
# Processed transfer 99 of 1486
# Processed transfer 100 of 1486
# Processed transfer 101 of 1486
# Processed transfer 102 of 1486
# Processed transfer 103 of 1486
# Processed transfer 104 of 1486
# Processed transfer 105 of 1486
# Processed transfer 106 of 1486
# Processed transfer 107 of 1486
# Processed transfer 108 of 1486
# Processed transfer 109 of 1486
# Processed transfer 110 of 1486
# Processed transfer 111 of 1486
# Processed transfer 112 of 1486
# Processed transfer 113 of 1486
# Processed transfer 114 of 1486
# Processed transfer 115 of 1486
# Processed transfer 116 of 1486
# Processed transfer 117 of 1486
# Processed transfer 118 of 1486
# Processed transfer 119 of 1486
# Processed transfer 120 of 1486
# Processed transfer 121 of 1486
# Processed transfer 122 of 1486
# Processed transfer 123 of 1486
# Processed transfer 124 of 1486
# Processed transfer 125 of 1486
# Processed transfer 126 of 1486
# Processed transfer 127 of 1486
# Processed transfer 128 of 1486
# Processed transfer 129 of 1486
# Processed transfer 130 of 1486
# Processed transfer 131 of 1486
# Processed transfer 132 of 1486
# Processed transfer 133 of 1486
# Processed transfer 134 of 1486
# Processed transfer 135 of 1486
# Processed transfer 136 of 1486
# Processed transfer 137 of 1486
# Processed transfer 138 of 1486
# Processed transfer 139 of 1486
# Processed transfer 140 of 1486
# Processed transfer 141 of 1486
# Processed transfer 142 of 1486
# Processed transfer 143 of 1486
# Processed transfer 144 of 1486
# Processed transfer 145 of 1486
# Processed transfer 146 of 1486
# Processed transfer 147 of 1486
# Processed transfer 148 of 1486
# Processed transfer 149 of 1486
# Processed transfer 150 of 1486
# Processed transfer 151 of 1486
# Processed transfer 152 of 1486
# Processed transfer 153 of 1486
# Processed transfer 154 of 1486
# Processed transfer 155 of 1486
# Processed transfer 156 of 1486
# Processed transfer 157 of 1486
# Processed transfer 158 of 1486
# Processed transfer 159 of 1486
# Processed transfer 160 of 1486
# Processed transfer 161 of 1486
# Processed transfer 162 of 1486
# Processed transfer 163 of 1486
# Processed transfer 164 of 1486
# Processed transfer 165 of 1486
# Processed transfer 166 of 1486
# Processed transfer 167 of 1486
# Processed transfer 168 of 1486
# Processed transfer 169 of 1486
# Processed transfer 170 of 1486
# Processed transfer 171 of 1486
# Processed transfer 172 of 1486
# Processed transfer 173 of 1486
# Processed transfer 174 of 1486
# Processed transfer 175 of 1486
# Processed transfer 176 of 1486
# Processed transfer 177 of 1486
# Processed transfer 178 of 1486
# Processed transfer 179 of 1486
# Processed transfer 180 of 1486
# Processed transfer 181 of 1486
# Processed transfer 182 of 1486
# Processed transfer 183 of 1486
# Processed transfer 184 of 1486
# Processed transfer 185 of 1486
# Processed transfer 186 of 1486
# Processed transfer 187 of 1486
# Processed transfer 188 of 1486
# Processed transfer 189 of 1486
# Processed transfer 190 of 1486
# Processed transfer 191 of 1486
# Processed transfer 192 of 1486
# Processed transfer 193 of 1486
# Processed transfer 194 of 1486
# Processed transfer 195 of 1486
# Processed transfer 196 of 1486
# Processed transfer 197 of 1486
# Processed transfer 198 of 1486
# Processed transfer 199 of 1486
# Processed transfer 200 of 1486
# Processed transfer 201 of 1486
# Processed transfer 202 of 1486
# Processed transfer 203 of 1486
# Processed transfer 204 of 1486
# Processed transfer 205 of 1486
# Processed transfer 206 of 1486
# Processed transfer 207 of 1486
# Processed transfer 208 of 1486
# Processed transfer 209 of 1486
# Processed transfer 210 of 1486
# Processed transfer 211 of 1486
# Processed transfer 212 of 1486
# Processed transfer 213 of 1486
# Processed transfer 214 of 1486
# Processed transfer 215 of 1486
# Processed transfer 216 of 1486
# Processed transfer 217 of 1486
# Processed transfer 218 of 1486
# Processed transfer 219 of 1486
# Processed transfer 220 of 1486
# Processed transfer 221 of 1486
# Processed transfer 222 of 1486
# Processed transfer 223 of 1486
# Processed transfer 224 of 1486
# Processed transfer 225 of 1486
# Processed transfer 226 of 1486
# Processed transfer 227 of 1486
# Processed transfer 228 of 1486
# Processed transfer 229 of 1486
# Processed transfer 230 of 1486
# Processed transfer 231 of 1486
# Processed transfer 232 of 1486
# Processed transfer 233 of 1486
# Processed transfer 234 of 1486
# Processed transfer 235 of 1486
# Processed transfer 236 of 1486
# Processed transfer 237 of 1486
# Processed transfer 238 of 1486
# Processed transfer 239 of 1486
# Processed transfer 240 of 1486
# Processed transfer 241 of 1486
# Processed transfer 242 of 1486
# Processed transfer 243 of 1486
# Processed transfer 244 of 1486
# Processed transfer 245 of 1486
# Processed transfer 246 of 1486
# Processed transfer 247 of 1486
# Processed transfer 248 of 1486
# Processed transfer 249 of 1486
# Processed transfer 250 of 1486
# Processed transfer 251 of 1486
# Processed transfer 252 of 1486
# Processed transfer 253 of 1486
# Processed transfer 254 of 1486
# Processed transfer 255 of 1486
# Processed transfer 256 of 1486
# Processed transfer 257 of 1486
# Processed transfer 258 of 1486
# Processed transfer 259 of 1486
# Processed transfer 260 of 1486
# Processed transfer 261 of 1486
# Processed transfer 262 of 1486
# Processed transfer 263 of 1486
# Processed transfer 264 of 1486
# Processed transfer 265 of 1486
# Processed transfer 266 of 1486
# Processed transfer 267 of 1486
# Processed transfer 268 of 1486
# Processed transfer 269 of 1486
# Processed transfer 270 of 1486
# Processed transfer 271 of 1486
# Processed transfer 272 of 1486
# Processed transfer 273 of 1486
# Processed transfer 274 of 1486
# Processed transfer 275 of 1486
# Processed transfer 276 of 1486
# Processed transfer 277 of 1486
# Processed transfer 278 of 1486
# Processed transfer 279 of 1486
# Processed transfer 280 of 1486
# Processed transfer 281 of 1486
# Processed transfer 282 of 1486
# Processed transfer 283 of 1486
# Processed transfer 284 of 1486
# Processed transfer 285 of 1486
# Processed transfer 286 of 1486
# Processed transfer 287 of 1486
# Processed transfer 288 of 1486
# Processed transfer 289 of 1486
# Processed transfer 290 of 1486
# Processed transfer 291 of 1486
# Processed transfer 292 of 1486
# Processed transfer 293 of 1486
# Processed transfer 294 of 1486
# Processed transfer 295 of 1486
# Processed transfer 296 of 1486
# Processed transfer 297 of 1486
# Processed transfer 298 of 1486
# Processed transfer 299 of 1486
# Processed transfer 300 of 1486
# Processed transfer 301 of 1486
# Processed transfer 302 of 1486
# Processed transfer 303 of 1486
# Processed transfer 304 of 1486
# Processed transfer 305 of 1486
# Processed transfer 306 of 1486
# Processed transfer 307 of 1486
# Processed transfer 308 of 1486
# Processed transfer 309 of 1486
# Processed transfer 310 of 1486
# Processed transfer 311 of 1486
# Processed transfer 312 of 1486
# Processed transfer 313 of 1486
# Processed transfer 314 of 1486
# Processed transfer 315 of 1486
# Processed transfer 316 of 1486
# Processed transfer 317 of 1486
# Processed transfer 318 of 1486
# Processed transfer 319 of 1486
# Processed transfer 320 of 1486
# Processed transfer 321 of 1486
# Processed transfer 322 of 1486
# Processed transfer 323 of 1486
# Processed transfer 324 of 1486
# Processed transfer 325 of 1486
# Processed transfer 326 of 1486
# Processed transfer 327 of 1486
# Processed transfer 328 of 1486
# Processed transfer 329 of 1486
# Processed transfer 330 of 1486
# Processed transfer 331 of 1486
# Processed transfer 332 of 1486
# Processed transfer 333 of 1486
# Processed transfer 334 of 1486
# Processed transfer 335 of 1486
# Processed transfer 336 of 1486
# Processed transfer 337 of 1486
# Processed transfer 338 of 1486
# Processed transfer 339 of 1486
# Processed transfer 340 of 1486
# Processed transfer 341 of 1486
# Processed transfer 342 of 1486
# Processed transfer 343 of 1486
# Processed transfer 344 of 1486
# Processed transfer 345 of 1486
# Processed transfer 346 of 1486
# Processed transfer 347 of 1486
# Processed transfer 348 of 1486
# Processed transfer 349 of 1486
# Processed transfer 350 of 1486
# Processed transfer 351 of 1486
# Processed transfer 352 of 1486
# Processed transfer 353 of 1486
# Processed transfer 354 of 1486
# Processed transfer 355 of 1486
# Processed transfer 356 of 1486
# Processed transfer 357 of 1486
# Processed transfer 358 of 1486
# Processed transfer 359 of 1486
# Processed transfer 360 of 1486
# Processed transfer 361 of 1486
# Processed transfer 362 of 1486
# Processed transfer 363 of 1486
# Processed transfer 364 of 1486
# Processed transfer 365 of 1486
# Processed transfer 366 of 1486
# Processed transfer 367 of 1486
# Processed transfer 368 of 1486
# Processed transfer 369 of 1486
# Processed transfer 370 of 1486
# Processed transfer 371 of 1486
# Processed transfer 372 of 1486
# Processed transfer 373 of 1486
# Processed transfer 374 of 1486
# Processed transfer 375 of 1486
# Processed transfer 376 of 1486
# Processed transfer 377 of 1486
# Processed transfer 378 of 1486
# Processed transfer 379 of 1486
# Processed transfer 380 of 1486
# Processed transfer 381 of 1486
# Processed transfer 382 of 1486
# Processed transfer 383 of 1486
# Processed transfer 384 of 1486
# Processed transfer 385 of 1486
# Processed transfer 386 of 1486
# Processed transfer 387 of 1486
# Processed transfer 388 of 1486
# Processed transfer 389 of 1486
# Processed transfer 390 of 1486
# Processed transfer 391 of 1486
# Processed transfer 392 of 1486
# Processed transfer 393 of 1486
# Processed transfer 394 of 1486
# Processed transfer 395 of 1486
# Processed transfer 396 of 1486
# Processed transfer 397 of 1486
# Processed transfer 398 of 1486
# Processed transfer 399 of 1486
# Processed transfer 400 of 1486
# Processed transfer 401 of 1486
# Processed transfer 402 of 1486
# Processed transfer 403 of 1486
# Processed transfer 404 of 1486
# Processed transfer 405 of 1486
# Processed transfer 406 of 1486
# Processed transfer 407 of 1486
# Processed transfer 408 of 1486
# Processed transfer 409 of 1486
# Processed transfer 410 of 1486
# Processed transfer 411 of 1486
# Processed transfer 412 of 1486
# Processed transfer 413 of 1486
# Processed transfer 414 of 1486
# Processed transfer 415 of 1486
# Processed transfer 416 of 1486
# Processed transfer 417 of 1486
# Processed transfer 418 of 1486
# Processed transfer 419 of 1486
# Processed transfer 420 of 1486
# Processed transfer 421 of 1486
# Processed transfer 422 of 1486
# Processed transfer 423 of 1486
# Processed transfer 424 of 1486
# Processed transfer 425 of 1486
# Processed transfer 426 of 1486
# Processed transfer 427 of 1486
# Processed transfer 428 of 1486
# Processed transfer 429 of 1486
# Processed transfer 430 of 1486
# Processed transfer 431 of 1486
# Processed transfer 432 of 1486
# Processed transfer 433 of 1486
# Processed transfer 434 of 1486
# Processed transfer 435 of 1486
# Processed transfer 436 of 1486
# Processed transfer 437 of 1486
# Processed transfer 438 of 1486
# Processed transfer 439 of 1486
# Processed transfer 440 of 1486
# Processed transfer 441 of 1486
# Processed transfer 442 of 1486
# Processed transfer 443 of 1486
# Processed transfer 444 of 1486
# Processed transfer 445 of 1486
# Processed transfer 446 of 1486
# Processed transfer 447 of 1486
# Processed transfer 448 of 1486
# Processed transfer 449 of 1486
# Processed transfer 450 of 1486
# Processed transfer 451 of 1486
# Processed transfer 452 of 1486
# Processed transfer 453 of 1486
# Processed transfer 454 of 1486
# Processed transfer 455 of 1486
# Processed transfer 456 of 1486
# Processed transfer 457 of 1486
# Processed transfer 458 of 1486
# Processed transfer 459 of 1486
# Processed transfer 460 of 1486
# Processed transfer 461 of 1486
# Processed transfer 462 of 1486
# Processed transfer 463 of 1486
# Processed transfer 464 of 1486
# Processed transfer 465 of 1486
# Processed transfer 466 of 1486
# Processed transfer 467 of 1486
# Processed transfer 468 of 1486
# Processed transfer 469 of 1486
# Processed transfer 470 of 1486
# Processed transfer 471 of 1486
# Processed transfer 472 of 1486
# Processed transfer 473 of 1486
# Processed transfer 474 of 1486
# Processed transfer 475 of 1486
# Processed transfer 476 of 1486
# Processed transfer 477 of 1486
# Processed transfer 478 of 1486
# Processed transfer 479 of 1486
# Processed transfer 480 of 1486
# Processed transfer 481 of 1486
# Processed transfer 482 of 1486
# Processed transfer 483 of 1486
# Processed transfer 484 of 1486
# Processed transfer 485 of 1486
# Processed transfer 486 of 1486
# Processed transfer 487 of 1486
# Processed transfer 488 of 1486
# Processed transfer 489 of 1486
# Processed transfer 490 of 1486
# Processed transfer 491 of 1486
# Processed transfer 492 of 1486
# Processed transfer 493 of 1486
# Processed transfer 494 of 1486
# Processed transfer 495 of 1486
# Processed transfer 496 of 1486
# Processed transfer 497 of 1486
# Processed transfer 498 of 1486
# Processed transfer 499 of 1486
# Processed transfer 500 of 1486
# Processed transfer 501 of 1486
# Processed transfer 502 of 1486
# Processed transfer 503 of 1486
# Processed transfer 504 of 1486
# Processed transfer 505 of 1486
# Processed transfer 506 of 1486
# Processed transfer 507 of 1486
# Processed transfer 508 of 1486
# Processed transfer 509 of 1486
# Processed transfer 510 of 1486
# Processed transfer 511 of 1486
# Processed transfer 512 of 1486
# Processed transfer 513 of 1486
# Processed transfer 514 of 1486
# Processed transfer 515 of 1486
# Processed transfer 516 of 1486
# Processed transfer 517 of 1486
# Processed transfer 518 of 1486
# Processed transfer 519 of 1486
# Processed transfer 520 of 1486
# Processed transfer 521 of 1486
# Processed transfer 522 of 1486
# Processed transfer 523 of 1486
# Processed transfer 524 of 1486
# Processed transfer 525 of 1486
# Processed transfer 526 of 1486
# Processed transfer 527 of 1486
# Processed transfer 528 of 1486
# Processed transfer 529 of 1486
# Processed transfer 530 of 1486
# Processed transfer 531 of 1486
# Processed transfer 532 of 1486
# Processed transfer 533 of 1486
# Processed transfer 534 of 1486
# Processed transfer 535 of 1486
# Processed transfer 536 of 1486
# Processed transfer 537 of 1486
# Processed transfer 538 of 1486
# Processed transfer 539 of 1486
# Processed transfer 540 of 1486
# Processed transfer 541 of 1486
# Processed transfer 542 of 1486
# Processed transfer 543 of 1486
# Processed transfer 544 of 1486
# Processed transfer 545 of 1486
# Processed transfer 546 of 1486
# Processed transfer 547 of 1486
# Processed transfer 548 of 1486
# Processed transfer 549 of 1486
# Processed transfer 550 of 1486
# Processed transfer 551 of 1486
# Processed transfer 552 of 1486
# Processed transfer 553 of 1486
# Processed transfer 554 of 1486
# Processed transfer 555 of 1486
# Processed transfer 556 of 1486
# Processed transfer 557 of 1486
# Processed transfer 558 of 1486
# Processed transfer 559 of 1486
# Processed transfer 560 of 1486
# Processed transfer 561 of 1486
# Processed transfer 562 of 1486
# Processed transfer 563 of 1486
# Processed transfer 564 of 1486
# Processed transfer 565 of 1486
# Processed transfer 566 of 1486
# Processed transfer 567 of 1486
# Processed transfer 568 of 1486
# Processed transfer 569 of 1486
# Processed transfer 570 of 1486
# Processed transfer 571 of 1486
# Processed transfer 572 of 1486
# Processed transfer 573 of 1486
# Processed transfer 574 of 1486
# Processed transfer 575 of 1486
# Processed transfer 576 of 1486
# Processed transfer 577 of 1486
# Processed transfer 578 of 1486
# Processed transfer 579 of 1486
# Processed transfer 580 of 1486
# Processed transfer 581 of 1486
# Processed transfer 582 of 1486
# Processed transfer 583 of 1486
# Processed transfer 584 of 1486
# Processed transfer 585 of 1486
# Processed transfer 586 of 1486
# Processed transfer 587 of 1486
# Processed transfer 588 of 1486
# Processed transfer 589 of 1486
# Processed transfer 590 of 1486
# Processed transfer 591 of 1486
# Processed transfer 592 of 1486
# Processed transfer 593 of 1486
# Processed transfer 594 of 1486
# Processed transfer 595 of 1486
# Processed transfer 596 of 1486
# Processed transfer 597 of 1486
# Processed transfer 598 of 1486
# Processed transfer 599 of 1486
# Processed transfer 600 of 1486
# Processed transfer 601 of 1486
# Processed transfer 602 of 1486
# Processed transfer 603 of 1486
# Processed transfer 604 of 1486
# Processed transfer 605 of 1486
# Processed transfer 606 of 1486
# Processed transfer 607 of 1486
# Processed transfer 608 of 1486
# Processed transfer 609 of 1486
# Processed transfer 610 of 1486
# Processed transfer 611 of 1486
# Processed transfer 612 of 1486
# Processed transfer 613 of 1486
# Processed transfer 614 of 1486
# Processed transfer 615 of 1486
# Processed transfer 616 of 1486
# Processed transfer 617 of 1486
# Processed transfer 618 of 1486
# Processed transfer 619 of 1486
# Processed transfer 620 of 1486
# Processed transfer 621 of 1486
# Processed transfer 622 of 1486
# Processed transfer 623 of 1486
# Processed transfer 624 of 1486
# Processed transfer 625 of 1486
# Processed transfer 626 of 1486
# Processed transfer 627 of 1486
# Processed transfer 628 of 1486
# Processed transfer 629 of 1486
# Processed transfer 630 of 1486
# Processed transfer 631 of 1486
# Processed transfer 632 of 1486
# Processed transfer 633 of 1486
# Processed transfer 634 of 1486
# Processed transfer 635 of 1486
# Processed transfer 636 of 1486
# Processed transfer 637 of 1486
# Processed transfer 638 of 1486
# Processed transfer 639 of 1486
# Processed transfer 640 of 1486
# Processed transfer 641 of 1486
# Processed transfer 642 of 1486
# Processed transfer 643 of 1486
# Processed transfer 644 of 1486
# Processed transfer 645 of 1486
# Processed transfer 646 of 1486
# Processed transfer 647 of 1486
# Processed transfer 648 of 1486
# Processed transfer 649 of 1486
# Processed transfer 650 of 1486
# Processed transfer 651 of 1486
# Processed transfer 652 of 1486
# Processed transfer 653 of 1486
# Processed transfer 654 of 1486
# Processed transfer 655 of 1486
# Processed transfer 656 of 1486
# Processed transfer 657 of 1486
# Processed transfer 658 of 1486
# Processed transfer 659 of 1486
# Processed transfer 660 of 1486
# Processed transfer 661 of 1486
# Processed transfer 662 of 1486
# Processed transfer 663 of 1486
# Processed transfer 664 of 1486
# Processed transfer 665 of 1486
# Processed transfer 666 of 1486
# Processed transfer 667 of 1486
# Processed transfer 668 of 1486
# Processed transfer 669 of 1486
# Processed transfer 670 of 1486
# Processed transfer 671 of 1486
# Processed transfer 672 of 1486
# Processed transfer 673 of 1486
# Processed transfer 674 of 1486
# Processed transfer 675 of 1486
# Processed transfer 676 of 1486
# Processed transfer 677 of 1486
# Processed transfer 678 of 1486
# Processed transfer 679 of 1486
# Processed transfer 680 of 1486
# Processed transfer 681 of 1486
# Processed transfer 682 of 1486
# Processed transfer 683 of 1486
# Processed transfer 684 of 1486
# Processed transfer 685 of 1486
# Processed transfer 686 of 1486
# Processed transfer 687 of 1486
# Processed transfer 688 of 1486
# Processed transfer 689 of 1486
# Processed transfer 690 of 1486
# Processed transfer 691 of 1486
# Processed transfer 692 of 1486
# Processed transfer 693 of 1486
# Processed transfer 694 of 1486
# Processed transfer 695 of 1486
# Processed transfer 696 of 1486
# Processed transfer 697 of 1486
# Processed transfer 698 of 1486
# Processed transfer 699 of 1486
# Processed transfer 700 of 1486
# Processed transfer 701 of 1486
# Processed transfer 702 of 1486
# Processed transfer 703 of 1486
# Processed transfer 704 of 1486
# Processed transfer 705 of 1486
# Processed transfer 706 of 1486
# Processed transfer 707 of 1486
# Processed transfer 708 of 1486
# Processed transfer 709 of 1486
# Processed transfer 710 of 1486
# Processed transfer 711 of 1486
# Processed transfer 712 of 1486
# Processed transfer 713 of 1486
# Processed transfer 714 of 1486
# Processed transfer 715 of 1486
# Processed transfer 716 of 1486
# Processed transfer 717 of 1486
# Processed transfer 718 of 1486
# Processed transfer 719 of 1486
# Processed transfer 720 of 1486
# Processed transfer 721 of 1486
# Processed transfer 722 of 1486
# Processed transfer 723 of 1486
# Processed transfer 724 of 1486
# Processed transfer 725 of 1486
# Processed transfer 726 of 1486
# Processed transfer 727 of 1486
# Processed transfer 728 of 1486
# Processed transfer 729 of 1486
# Processed transfer 730 of 1486
# Processed transfer 731 of 1486
# Processed transfer 732 of 1486
# Processed transfer 733 of 1486
# Processed transfer 734 of 1486
# Processed transfer 735 of 1486
# Processed transfer 736 of 1486
# Processed transfer 737 of 1486
# Processed transfer 738 of 1486
# Processed transfer 739 of 1486
# Processed transfer 740 of 1486
# Processed transfer 741 of 1486
# Processed transfer 742 of 1486
# Processed transfer 743 of 1486
# Processed transfer 744 of 1486
# Processed transfer 745 of 1486
# Processed transfer 746 of 1486
# Processed transfer 747 of 1486
# Processed transfer 748 of 1486
# Processed transfer 749 of 1486
# Processed transfer 750 of 1486
# Processed transfer 751 of 1486
# Processed transfer 752 of 1486
# Processed transfer 753 of 1486
# Processed transfer 754 of 1486
# Processed transfer 755 of 1486
# Processed transfer 756 of 1486
# Processed transfer 757 of 1486
# Processed transfer 758 of 1486
# Processed transfer 759 of 1486
# Processed transfer 760 of 1486
# Processed transfer 761 of 1486
# Processed transfer 762 of 1486
# Processed transfer 763 of 1486
# Processed transfer 764 of 1486
# Processed transfer 765 of 1486
# Processed transfer 766 of 1486
# Processed transfer 767 of 1486
# Processed transfer 768 of 1486
# Processed transfer 769 of 1486
# Processed transfer 770 of 1486
# Processed transfer 771 of 1486
# Processed transfer 772 of 1486
# Processed transfer 773 of 1486
# Processed transfer 774 of 1486
# Processed transfer 775 of 1486
# Processed transfer 776 of 1486
# Processed transfer 777 of 1486
# Processed transfer 778 of 1486
# Processed transfer 779 of 1486
# Processed transfer 780 of 1486
# Processed transfer 781 of 1486
# Processed transfer 782 of 1486
# Processed transfer 783 of 1486
# Processed transfer 784 of 1486
# Processed transfer 785 of 1486
# Processed transfer 786 of 1486
# Processed transfer 787 of 1486
# Processed transfer 788 of 1486
# Processed transfer 789 of 1486
# Processed transfer 790 of 1486
# Processed transfer 791 of 1486
# Processed transfer 792 of 1486
# Processed transfer 793 of 1486
# Processed transfer 794 of 1486
# Processed transfer 795 of 1486
# Processed transfer 796 of 1486
# Processed transfer 797 of 1486
# Processed transfer 798 of 1486
# Processed transfer 799 of 1486
# Processed transfer 800 of 1486
# Processed transfer 801 of 1486
# Processed transfer 802 of 1486
# Processed transfer 803 of 1486
# Processed transfer 804 of 1486
# Processed transfer 805 of 1486
# Processed transfer 806 of 1486
# Processed transfer 807 of 1486
# Processed transfer 808 of 1486
# Processed transfer 809 of 1486
# Processed transfer 810 of 1486
# Processed transfer 811 of 1486
# Processed transfer 812 of 1486
# Processed transfer 813 of 1486
# Processed transfer 814 of 1486
# Processed transfer 815 of 1486
# Processed transfer 816 of 1486
# Processed transfer 817 of 1486
# Processed transfer 818 of 1486
# Processed transfer 819 of 1486
# Processed transfer 820 of 1486
# Processed transfer 821 of 1486
# Processed transfer 822 of 1486
# Processed transfer 823 of 1486
# Processed transfer 824 of 1486
# Processed transfer 825 of 1486
# Processed transfer 826 of 1486
# Processed transfer 827 of 1486
# Processed transfer 828 of 1486
# Processed transfer 829 of 1486
# Processed transfer 830 of 1486
# Processed transfer 831 of 1486
# Processed transfer 832 of 1486
# Processed transfer 833 of 1486
# Processed transfer 834 of 1486
# Processed transfer 835 of 1486
# Processed transfer 836 of 1486
# Processed transfer 837 of 1486
# Processed transfer 838 of 1486
# Processed transfer 839 of 1486
# Processed transfer 840 of 1486
# Processed transfer 841 of 1486
# Processed transfer 842 of 1486
# Processed transfer 843 of 1486
# Processed transfer 844 of 1486
# Processed transfer 845 of 1486
# Processed transfer 846 of 1486
# Processed transfer 847 of 1486
# Processed transfer 848 of 1486
# Processed transfer 849 of 1486
# Processed transfer 850 of 1486
# Processed transfer 851 of 1486
# Processed transfer 852 of 1486
# Processed transfer 853 of 1486
# Processed transfer 854 of 1486
# Processed transfer 855 of 1486
# Processed transfer 856 of 1486
# Processed transfer 857 of 1486
# Processed transfer 858 of 1486
# Processed transfer 859 of 1486
# Processed transfer 860 of 1486
# Processed transfer 861 of 1486
# Processed transfer 862 of 1486
# Processed transfer 863 of 1486
# Processed transfer 864 of 1486
# Processed transfer 865 of 1486
# Processed transfer 866 of 1486
# Processed transfer 867 of 1486
# Processed transfer 868 of 1486
# Processed transfer 869 of 1486
# Processed transfer 870 of 1486
# Processed transfer 871 of 1486
# Processed transfer 872 of 1486
# Processed transfer 873 of 1486
# Processed transfer 874 of 1486
# Processed transfer 875 of 1486
# Processed transfer 876 of 1486
# Processed transfer 877 of 1486
# Processed transfer 878 of 1486
# Processed transfer 879 of 1486
# Processed transfer 880 of 1486
# Processed transfer 881 of 1486
# Processed transfer 882 of 1486
# Processed transfer 883 of 1486
# Processed transfer 884 of 1486
# Processed transfer 885 of 1486
# Processed transfer 886 of 1486
# Processed transfer 887 of 1486
# Processed transfer 888 of 1486
# Processed transfer 889 of 1486
# Processed transfer 890 of 1486
# Processed transfer 891 of 1486
# Processed transfer 892 of 1486
# Processed transfer 893 of 1486
# Processed transfer 894 of 1486
# Processed transfer 895 of 1486
# Processed transfer 896 of 1486
# Processed transfer 897 of 1486
# Processed transfer 898 of 1486
# Processed transfer 899 of 1486
# Processed transfer 900 of 1486
# Processed transfer 901 of 1486
# Processed transfer 902 of 1486
# Processed transfer 903 of 1486
# Processed transfer 904 of 1486
# Processed transfer 905 of 1486
# Processed transfer 906 of 1486
# Processed transfer 907 of 1486
# Processed transfer 908 of 1486
# Processed transfer 909 of 1486
# Processed transfer 910 of 1486
# Processed transfer 911 of 1486
# Processed transfer 912 of 1486
# Processed transfer 913 of 1486
# Processed transfer 914 of 1486
# Processed transfer 915 of 1486
# Processed transfer 916 of 1486
# Processed transfer 917 of 1486
# Processed transfer 918 of 1486
# Processed transfer 919 of 1486
# Processed transfer 920 of 1486
# Processed transfer 921 of 1486
# Processed transfer 922 of 1486
# Processed transfer 923 of 1486
# Processed transfer 924 of 1486
# Processed transfer 925 of 1486
# Processed transfer 926 of 1486
# Processed transfer 927 of 1486
# Processed transfer 928 of 1486
# Processed transfer 929 of 1486
# Processed transfer 930 of 1486
# Processed transfer 931 of 1486
# Processed transfer 932 of 1486
# Processed transfer 933 of 1486
# Processed transfer 934 of 1486
# Processed transfer 935 of 1486
# Processed transfer 936 of 1486
# Processed transfer 937 of 1486
# Processed transfer 938 of 1486
# Processed transfer 939 of 1486
# Processed transfer 940 of 1486
# Processed transfer 941 of 1486
# Processed transfer 942 of 1486
# Processed transfer 943 of 1486
# Processed transfer 944 of 1486
# Processed transfer 945 of 1486
# Processed transfer 946 of 1486
# Processed transfer 947 of 1486
# Processed transfer 948 of 1486
# Processed transfer 949 of 1486
# Processed transfer 950 of 1486
# Processed transfer 951 of 1486
# Processed transfer 952 of 1486
# Processed transfer 953 of 1486
# Processed transfer 954 of 1486
# Processed transfer 955 of 1486
# Processed transfer 956 of 1486
# Processed transfer 957 of 1486
# Processed transfer 958 of 1486
# Processed transfer 959 of 1486
# Processed transfer 960 of 1486
# Processed transfer 961 of 1486
# Processed transfer 962 of 1486
# Processed transfer 963 of 1486
# Processed transfer 964 of 1486
# Processed transfer 965 of 1486
# Processed transfer 966 of 1486
# Processed transfer 967 of 1486
# Processed transfer 968 of 1486
# Processed transfer 969 of 1486
# Processed transfer 970 of 1486
# Processed transfer 971 of 1486
# Processed transfer 972 of 1486
# Processed transfer 973 of 1486
# Processed transfer 974 of 1486
# Processed transfer 975 of 1486
# Processed transfer 976 of 1486
# Processed transfer 977 of 1486
# Processed transfer 978 of 1486
# Processed transfer 979 of 1486
# Processed transfer 980 of 1486
# Processed transfer 981 of 1486
# Processed transfer 982 of 1486
# Processed transfer 983 of 1486
# Processed transfer 984 of 1486
# Processed transfer 985 of 1486
# Processed transfer 986 of 1486
# Processed transfer 987 of 1486
# Processed transfer 988 of 1486
# Processed transfer 989 of 1486
# Processed transfer 990 of 1486
# Processed transfer 991 of 1486
# Processed transfer 992 of 1486
# Processed transfer 993 of 1486
# Processed transfer 994 of 1486
# Processed transfer 995 of 1486
# Processed transfer 996 of 1486
# Processed transfer 997 of 1486
# Processed transfer 998 of 1486
# Processed transfer 999 of 1486
# Processed transfer 1000 of 1486
# Processed transfer 1001 of 1486
# Processed transfer 1002 of 1486
# Processed transfer 1003 of 1486
# Processed transfer 1004 of 1486
# Processed transfer 1005 of 1486
# Processed transfer 1006 of 1486
# Processed transfer 1007 of 1486
# Processed transfer 1008 of 1486
# Processed transfer 1009 of 1486
# Processed transfer 1010 of 1486
# Processed transfer 1011 of 1486
# Processed transfer 1012 of 1486
# Processed transfer 1013 of 1486
# Processed transfer 1014 of 1486
# Processed transfer 1015 of 1486
# Processed transfer 1016 of 1486
# Processed transfer 1017 of 1486
# Processed transfer 1018 of 1486
# Processed transfer 1019 of 1486
# Processed transfer 1020 of 1486
# Processed transfer 1021 of 1486
# Processed transfer 1022 of 1486
# Processed transfer 1023 of 1486
# Processed transfer 1024 of 1486
# Processed transfer 1025 of 1486
# Processed transfer 1026 of 1486
# Processed transfer 1027 of 1486
# Processed transfer 1028 of 1486
# Processed transfer 1029 of 1486
# Processed transfer 1030 of 1486
# Processed transfer 1031 of 1486
# Processed transfer 1032 of 1486
# Processed transfer 1033 of 1486
# Processed transfer 1034 of 1486
# Processed transfer 1035 of 1486
# Processed transfer 1036 of 1486
# Processed transfer 1037 of 1486
# Processed transfer 1038 of 1486
# Processed transfer 1039 of 1486
# Processed transfer 1040 of 1486
# Processed transfer 1041 of 1486
# Processed transfer 1042 of 1486
# Processed transfer 1043 of 1486
# Processed transfer 1044 of 1486
# Processed transfer 1045 of 1486
# Processed transfer 1046 of 1486
# Processed transfer 1047 of 1486
# Processed transfer 1048 of 1486
# Processed transfer 1049 of 1486
# Processed transfer 1050 of 1486
# Processed transfer 1051 of 1486
# Processed transfer 1052 of 1486
# Processed transfer 1053 of 1486
# Processed transfer 1054 of 1486
# Processed transfer 1055 of 1486
# Processed transfer 1056 of 1486
# Processed transfer 1057 of 1486
# Processed transfer 1058 of 1486
# Processed transfer 1059 of 1486
# Processed transfer 1060 of 1486
# Processed transfer 1061 of 1486
# Processed transfer 1062 of 1486
# Processed transfer 1063 of 1486
# Processed transfer 1064 of 1486
# Processed transfer 1065 of 1486
# Processed transfer 1066 of 1486
# Processed transfer 1067 of 1486
# Processed transfer 1068 of 1486
# Processed transfer 1069 of 1486
# Processed transfer 1070 of 1486
# Processed transfer 1071 of 1486
# Processed transfer 1072 of 1486
# Processed transfer 1073 of 1486
# Processed transfer 1074 of 1486
# Processed transfer 1075 of 1486
# Processed transfer 1076 of 1486
# Processed transfer 1077 of 1486
# Processed transfer 1078 of 1486
# Processed transfer 1079 of 1486
# Processed transfer 1080 of 1486
# Processed transfer 1081 of 1486
# Processed transfer 1082 of 1486
# Processed transfer 1083 of 1486
# Processed transfer 1084 of 1486
# Processed transfer 1085 of 1486
# Processed transfer 1086 of 1486
# Processed transfer 1087 of 1486
# Processed transfer 1088 of 1486
# Processed transfer 1089 of 1486
# Processed transfer 1090 of 1486
# Processed transfer 1091 of 1486
# Processed transfer 1092 of 1486
# Processed transfer 1093 of 1486
# Processed transfer 1094 of 1486
# Processed transfer 1095 of 1486
# Processed transfer 1096 of 1486
# Processed transfer 1097 of 1486
# Processed transfer 1098 of 1486
# Processed transfer 1099 of 1486
# Processed transfer 1100 of 1486
# Processed transfer 1101 of 1486
# Processed transfer 1102 of 1486
# Processed transfer 1103 of 1486
# Processed transfer 1104 of 1486
# Processed transfer 1105 of 1486
# Processed transfer 1106 of 1486
# Processed transfer 1107 of 1486
# Processed transfer 1108 of 1486
# Processed transfer 1109 of 1486
# Processed transfer 1110 of 1486
# Processed transfer 1111 of 1486
# Processed transfer 1112 of 1486
# Processed transfer 1113 of 1486
# Processed transfer 1114 of 1486
# Processed transfer 1115 of 1486
# Processed transfer 1116 of 1486
# Processed transfer 1117 of 1486
# Processed transfer 1118 of 1486
# Processed transfer 1119 of 1486
# Processed transfer 1120 of 1486
# Processed transfer 1121 of 1486
# Processed transfer 1122 of 1486
# Processed transfer 1123 of 1486
# Processed transfer 1124 of 1486
# Processed transfer 1125 of 1486
# Processed transfer 1126 of 1486
# Processed transfer 1127 of 1486
# Processed transfer 1128 of 1486
# Processed transfer 1129 of 1486
# Processed transfer 1130 of 1486
# Processed transfer 1131 of 1486
# Processed transfer 1132 of 1486
# Processed transfer 1133 of 1486
# Processed transfer 1134 of 1486
# Processed transfer 1135 of 1486
# Processed transfer 1136 of 1486
# Processed transfer 1137 of 1486
# Processed transfer 1138 of 1486
# Processed transfer 1139 of 1486
# Processed transfer 1140 of 1486
# Processed transfer 1141 of 1486
# Processed transfer 1142 of 1486
# Processed transfer 1143 of 1486
# Processed transfer 1144 of 1486
# Processed transfer 1145 of 1486
# Processed transfer 1146 of 1486
# Processed transfer 1147 of 1486
# Processed transfer 1148 of 1486
# Processed transfer 1149 of 1486
# Processed transfer 1150 of 1486
# Processed transfer 1151 of 1486
# Processed transfer 1152 of 1486
# Processed transfer 1153 of 1486
# Processed transfer 1154 of 1486
# Processed transfer 1155 of 1486
# Processed transfer 1156 of 1486
# Processed transfer 1157 of 1486
# Processed transfer 1158 of 1486
# Processed transfer 1159 of 1486
# Processed transfer 1160 of 1486
# Processed transfer 1161 of 1486
# Processed transfer 1162 of 1486
# Processed transfer 1163 of 1486
# Processed transfer 1164 of 1486
# Processed transfer 1165 of 1486
# Processed transfer 1166 of 1486
# Processed transfer 1167 of 1486
# Processed transfer 1168 of 1486
# Processed transfer 1169 of 1486
# Processed transfer 1170 of 1486
# Processed transfer 1171 of 1486
# Processed transfer 1172 of 1486
# Processed transfer 1173 of 1486
# Processed transfer 1174 of 1486
# Processed transfer 1175 of 1486
# Processed transfer 1176 of 1486
# Processed transfer 1177 of 1486
# Processed transfer 1178 of 1486
# Processed transfer 1179 of 1486
# Processed transfer 1180 of 1486
# Processed transfer 1181 of 1486
# Processed transfer 1182 of 1486
# Processed transfer 1183 of 1486
# Processed transfer 1184 of 1486
# Processed transfer 1185 of 1486
# Processed transfer 1186 of 1486
# Processed transfer 1187 of 1486
# Processed transfer 1188 of 1486
# Processed transfer 1189 of 1486
# Processed transfer 1190 of 1486
# Processed transfer 1191 of 1486
# Processed transfer 1192 of 1486
# Processed transfer 1193 of 1486
# Processed transfer 1194 of 1486
# Processed transfer 1195 of 1486
# Processed transfer 1196 of 1486
# Processed transfer 1197 of 1486
# Processed transfer 1198 of 1486
# Processed transfer 1199 of 1486
# Processed transfer 1200 of 1486
# Processed transfer 1201 of 1486
# Processed transfer 1202 of 1486
# Processed transfer 1203 of 1486
# Processed transfer 1204 of 1486
# Processed transfer 1205 of 1486
# Processed transfer 1206 of 1486
# Processed transfer 1207 of 1486
# Processed transfer 1208 of 1486
# Processed transfer 1209 of 1486
# Processed transfer 1210 of 1486
# Processed transfer 1211 of 1486
# Processed transfer 1212 of 1486
# Processed transfer 1213 of 1486
# Processed transfer 1214 of 1486
# Processed transfer 1215 of 1486
# Processed transfer 1216 of 1486
# Processed transfer 1217 of 1486
# Processed transfer 1218 of 1486
# Processed transfer 1219 of 1486
# Processed transfer 1220 of 1486
# Processed transfer 1221 of 1486
# Processed transfer 1222 of 1486
# Processed transfer 1223 of 1486
# Processed transfer 1224 of 1486
# Processed transfer 1225 of 1486
# Processed transfer 1226 of 1486
# Processed transfer 1227 of 1486
# Processed transfer 1228 of 1486
# Processed transfer 1229 of 1486
# Processed transfer 1230 of 1486
# Processed transfer 1231 of 1486
# Processed transfer 1232 of 1486
# Processed transfer 1233 of 1486
# Processed transfer 1234 of 1486
# Processed transfer 1235 of 1486
# Processed transfer 1236 of 1486
# Processed transfer 1237 of 1486
# Processed transfer 1238 of 1486
# Processed transfer 1239 of 1486
# Processed transfer 1240 of 1486
# Processed transfer 1241 of 1486
# Processed transfer 1242 of 1486
# Processed transfer 1243 of 1486
# Processed transfer 1244 of 1486
# Processed transfer 1245 of 1486
# Processed transfer 1246 of 1486
# Processed transfer 1247 of 1486
# Processed transfer 1248 of 1486
# Processed transfer 1249 of 1486
# Processed transfer 1250 of 1486
# Processed transfer 1251 of 1486
# Processed transfer 1252 of 1486
# Processed transfer 1253 of 1486
# Processed transfer 1254 of 1486
# Processed transfer 1255 of 1486
# Processed transfer 1256 of 1486
# Processed transfer 1257 of 1486
# Processed transfer 1258 of 1486
# Processed transfer 1259 of 1486
# Processed transfer 1260 of 1486
# Processed transfer 1261 of 1486
# Processed transfer 1262 of 1486
# Processed transfer 1263 of 1486
# Processed transfer 1264 of 1486
# Processed transfer 1265 of 1486
# Processed transfer 1266 of 1486
# Processed transfer 1267 of 1486
# Processed transfer 1268 of 1486
# Processed transfer 1269 of 1486
# Processed transfer 1270 of 1486
# Processed transfer 1271 of 1486
# Processed transfer 1272 of 1486
# Processed transfer 1273 of 1486
# Processed transfer 1274 of 1486
# Processed transfer 1275 of 1486
# Processed transfer 1276 of 1486
# Processed transfer 1277 of 1486
# Processed transfer 1278 of 1486
# Processed transfer 1279 of 1486
# Processed transfer 1280 of 1486
# Processed transfer 1281 of 1486
# Processed transfer 1282 of 1486
# Processed transfer 1283 of 1486
# Processed transfer 1284 of 1486
# Processed transfer 1285 of 1486
# Processed transfer 1286 of 1486
# Processed transfer 1287 of 1486
# Processed transfer 1288 of 1486
# Processed transfer 1289 of 1486
# Processed transfer 1290 of 1486
# Processed transfer 1291 of 1486
# Processed transfer 1292 of 1486
# Processed transfer 1293 of 1486
# Processed transfer 1294 of 1486
# Processed transfer 1295 of 1486
# Processed transfer 1296 of 1486
# Processed transfer 1297 of 1486
# Processed transfer 1298 of 1486
# Processed transfer 1299 of 1486
# Processed transfer 1300 of 1486
# Processed transfer 1301 of 1486
# Processed transfer 1302 of 1486
# Processed transfer 1303 of 1486
# Processed transfer 1304 of 1486
# Processed transfer 1305 of 1486
# Processed transfer 1306 of 1486
# Processed transfer 1307 of 1486
# Processed transfer 1308 of 1486
# Processed transfer 1309 of 1486
# Processed transfer 1310 of 1486
# Processed transfer 1311 of 1486
# Processed transfer 1312 of 1486
# Processed transfer 1313 of 1486
# Processed transfer 1314 of 1486
# Processed transfer 1315 of 1486
# Processed transfer 1316 of 1486
# Processed transfer 1317 of 1486
# Processed transfer 1318 of 1486
# Processed transfer 1319 of 1486
# Processed transfer 1320 of 1486
# Processed transfer 1321 of 1486
# Processed transfer 1322 of 1486
# Processed transfer 1323 of 1486
# Processed transfer 1324 of 1486
# Processed transfer 1325 of 1486
# Processed transfer 1326 of 1486
# Processed transfer 1327 of 1486
# Processed transfer 1328 of 1486
# Processed transfer 1329 of 1486
# Processed transfer 1330 of 1486
# Processed transfer 1331 of 1486
# Processed transfer 1332 of 1486
# Processed transfer 1333 of 1486
# Processed transfer 1334 of 1486
# Processed transfer 1335 of 1486
# Processed transfer 1336 of 1486
# Processed transfer 1337 of 1486
# Processed transfer 1338 of 1486
# Processed transfer 1339 of 1486
# Processed transfer 1340 of 1486
# Processed transfer 1341 of 1486
# Processed transfer 1342 of 1486
# Processed transfer 1343 of 1486
# Processed transfer 1344 of 1486
# Processed transfer 1345 of 1486
# Processed transfer 1346 of 1486
# Processed transfer 1347 of 1486
# Processed transfer 1348 of 1486
# Processed transfer 1349 of 1486
# Processed transfer 1350 of 1486
# Processed transfer 1351 of 1486
# Processed transfer 1352 of 1486
# Processed transfer 1353 of 1486
# Processed transfer 1354 of 1486
# Processed transfer 1355 of 1486
# Processed transfer 1356 of 1486
# Processed transfer 1357 of 1486
# Processed transfer 1358 of 1486
# Processed transfer 1359 of 1486
# Processed transfer 1360 of 1486
# Processed transfer 1361 of 1486
# Processed transfer 1362 of 1486
# Processed transfer 1363 of 1486
# Processed transfer 1364 of 1486
# Processed transfer 1365 of 1486
# Processed transfer 1366 of 1486
# Processed transfer 1367 of 1486
# Processed transfer 1368 of 1486
# Processed transfer 1369 of 1486
# Processed transfer 1370 of 1486
# Processed transfer 1371 of 1486
# Processed transfer 1372 of 1486
# Processed transfer 1373 of 1486
# Processed transfer 1374 of 1486
# Processed transfer 1375 of 1486
# Processed transfer 1376 of 1486
# Processed transfer 1377 of 1486
# Processed transfer 1378 of 1486
# Processed transfer 1379 of 1486
# Processed transfer 1380 of 1486
# Processed transfer 1381 of 1486
# Processed transfer 1382 of 1486
# Processed transfer 1383 of 1486
# Processed transfer 1384 of 1486
# Processed transfer 1385 of 1486
# Processed transfer 1386 of 1486
# Processed transfer 1387 of 1486
# Processed transfer 1388 of 1486
# Processed transfer 1389 of 1486
# Processed transfer 1390 of 1486
# Processed transfer 1391 of 1486
# Processed transfer 1392 of 1486
# Processed transfer 1393 of 1486
# Processed transfer 1394 of 1486
# Processed transfer 1395 of 1486
# Processed transfer 1396 of 1486
# Processed transfer 1397 of 1486
# Processed transfer 1398 of 1486
# Processed transfer 1399 of 1486
# Processed transfer 1400 of 1486
# Processed transfer 1401 of 1486
# Processed transfer 1402 of 1486
# Processed transfer 1403 of 1486
# Processed transfer 1404 of 1486
# Processed transfer 1405 of 1486
# Processed transfer 1406 of 1486
# Processed transfer 1407 of 1486
# Processed transfer 1408 of 1486
# Processed transfer 1409 of 1486
# Processed transfer 1410 of 1486
# Processed transfer 1411 of 1486
# Processed transfer 1412 of 1486
# Processed transfer 1413 of 1486
# Processed transfer 1414 of 1486
# Processed transfer 1415 of 1486
# Processed transfer 1416 of 1486
# Processed transfer 1417 of 1486
# Processed transfer 1418 of 1486
# Processed transfer 1419 of 1486
# Processed transfer 1420 of 1486
# Processed transfer 1421 of 1486
# Processed transfer 1422 of 1486
# Processed transfer 1423 of 1486
# Processed transfer 1424 of 1486
# Processed transfer 1425 of 1486
# Processed transfer 1426 of 1486
# Processed transfer 1427 of 1486
# Processed transfer 1428 of 1486
# Processed transfer 1429 of 1486
# Processed transfer 1430 of 1486
# Processed transfer 1431 of 1486
# Processed transfer 1432 of 1486
# Processed transfer 1433 of 1486
# Processed transfer 1434 of 1486
# Processed transfer 1435 of 1486
# Processed transfer 1436 of 1486
# Processed transfer 1437 of 1486
# Processed transfer 1438 of 1486
# Processed transfer 1439 of 1486
# Processed transfer 1440 of 1486
# Processed transfer 1441 of 1486
# Processed transfer 1442 of 1486
# Processed transfer 1443 of 1486
# Processed transfer 1444 of 1486
# Processed transfer 1445 of 1486
# Processed transfer 1446 of 1486
# Processed transfer 1447 of 1486
# Processed transfer 1448 of 1486
# Processed transfer 1449 of 1486
# Processed transfer 1450 of 1486
# Processed transfer 1451 of 1486
# Processed transfer 1452 of 1486
# Processed transfer 1453 of 1486
# Processed transfer 1454 of 1486
# Processed transfer 1455 of 1486
# Processed transfer 1456 of 1486
# Processed transfer 1457 of 1486
# Processed transfer 1458 of 1486
# Processed transfer 1459 of 1486
# Processed transfer 1460 of 1486
# Processed transfer 1461 of 1486
# Processed transfer 1462 of 1486
# Processed transfer 1463 of 1486
# Processed transfer 1464 of 1486
# Processed transfer 1465 of 1486
# Processed transfer 1466 of 1486
# Processed transfer 1467 of 1486
# Processed transfer 1468 of 1486
# Processed transfer 1469 of 1486
# Processed transfer 1470 of 1486
# Processed transfer 1471 of 1486
# Processed transfer 1472 of 1486
# Processed transfer 1473 of 1486
# Processed transfer 1474 of 1486
# Processed transfer 1475 of 1486
# Processed transfer 1476 of 1486
# Processed transfer 1477 of 1486
# Processed transfer 1478 of 1486
# Processed transfer 1479 of 1486
# Processed transfer 1480 of 1486
# Processed transfer 1481 of 1486
# Processed transfer 1482 of 1486
# Processed transfer 1483 of 1486
# Processed transfer 1484 of 1486
# Processed transfer 1485 of 1486
# Processed transfer 1486 of 1486
#              Player             From                To Position Week  Value  \
# 0             Alaba      Real Madrid   Go Ahead Eagles       CB   39  22.3M
# 1              Leno        Liverpool   Go Ahead Eagles       GK   39  21.2M
# 2             White      Real Madrid   Go Ahead Eagles       RB   39  15.6M
# 3            Mitoma        Barcelona   Go Ahead Eagles       LW   39  22.8M
# 4          Guirassy  Go Ahead Eagles           Arsenal       ST   38  12.3M
# ...             ...              ...               ...      ...  ...    ...
# 1481        Trauner        Feyenoord        CF Pachuca       CB    0   3.8M
# 1482  van Brederode               AZ           Udinese       LW    0   4.5M
# 1483       Rijkhoff             Ajax    Djurgårdens IF       ST    0   2.7M
# 1484       Sahraoui    SC Heerenveen  Atlético Mineiro       LW    0   4.9M
# 1485     Zsolt Nagy  Puskás Akadémia     SC Heerenveen       LB    0   2.3M
#
#       Price         Date
# 0     31.9M        06:11
# 1     26.7M        06:11
# 2     21.9M        06:11
# 3     28.3M        06:11
# 4     24.7M  4 September
# ...     ...          ...
# 1481   9.4M      24 July
# 1482   6.0M      24 July
# 1483   6.6M      24 July
# 1484  12.2M      24 July
# 1485   4.0M      24 July
#
# [1486 rows x 8 columns]

# %%
df
# Out:
#              Player             From                To Position Week  Value  \
# 0             Alaba      Real Madrid   Go Ahead Eagles       CB   39  22.3M
# 1              Leno        Liverpool   Go Ahead Eagles       GK   39  21.2M
# 2             White      Real Madrid   Go Ahead Eagles       RB   39  15.6M
# 3            Mitoma        Barcelona   Go Ahead Eagles       LW   39  22.8M
# 4          Guirassy  Go Ahead Eagles           Arsenal       ST   38  12.3M
# ...             ...              ...               ...      ...  ...    ...
# 1481        Trauner        Feyenoord        CF Pachuca       CB    0   3.8M
# 1482  van Brederode               AZ           Udinese       LW    0   4.5M
# 1483       Rijkhoff             Ajax    Djurgårdens IF       ST    0   2.7M
# 1484       Sahraoui    SC Heerenveen  Atlético Mineiro       LW    0   4.9M
# 1485     Zsolt Nagy  Puskás Akadémia     SC Heerenveen       LB    0   2.3M
#
#       Price         Date
# 0     31.9M        06:11
# 1     26.7M        06:11
# 2     21.9M        06:11
# 3     28.3M        06:11
# 4     24.7M  4 September
# ...     ...          ...
# 1481   9.4M      24 July
# 1482   6.0M      24 July
# 1483   6.6M      24 July
# 1484  12.2M      24 July
# 1485   4.0M      24 July
#
# [1486 rows x 8 columns]

# %%
df.to_csv("D:\Webscraping\player_transfers.csv", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\hoybr\AppData\Local\Temp\ipykernel_27780\1883705207.py:1: SyntaxWarning: invalid escape sequence '\W'
#   df.to_csv("D:\Webscraping\player_transfers.csv", index=False)

# %% [markdown]
# ## Collecting player data

# %%
# Wait for the page to load
wait = WebDriverWait(driver, 10)

# %%
df = pd.DataFrame()

# %%
# Initialize an empty list to store player data
players_data = []

# Find all rows in the table
rows = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "table tbody tr")))

# Team
team = driver.find_element(By.XPATH, "//h2[contains(@data-bind, 'name')]").text

# Iterate through each row
for row in rows:
    try:
        # Extract Player Name
        player_name = row.find_element(By.CSS_SELECTOR, "span.semi-bold.inline-block[data-bind='text: name']").text

        # Extract Position
        position = row.find_element(By.CSS_SELECTOR, "td.text-right").text.strip()

        # Extract Nationality
        nationality_element = row.find_element(By.CSS_SELECTOR, "span.flag-icon")
        nationality = nationality_element.get_attribute("title")

        # Extract Age
        age = row.find_element(By.CSS_SELECTOR, "td.hidden-xs.td-content-width.text-center.text-secondary[data-bind='text: age']").text

        # Extract Value
        value = row.find_element(By.CSS_SELECTOR, "span.club-funds-amount[data-bind='currency: value, roundCurrency: 1, fractionDigits: 1']").text

        # Append data to the list
        players_data.append({
            "Team": team,
            "Player": player_name,
            "Position": position,
            "Nationality": nationality,
            "Age": age,
            "Value": value
        })

        # Showing the progress
        print(f'{player_name} ({team})- A {age} years old {nationality} {position} with a value of £{value}.')

    except (NoSuchElementException, TimeoutException):
        # If any element is not found, skip this row and continue with the next
        continue
# Out:
# Wirtz (Heracles Almelo)- A 21 years old German CAM with a value of £21.8M.
# Thuram (Heracles Almelo)- A 27 years old French ST with a value of £18.5M.
# Núñez (Heracles Almelo)- A 25 years old Uruguayan ST with a value of £14.7M.
# Palmer (Heracles Almelo)- A 22 years old English CAM with a value of £13.6M.
# Batshuayi (Heracles Almelo)- A 30 years old Belgian ST with a value of £11.0M.
# Yüksek (Heracles Almelo)- A 25 years old Turkish CDM with a value of £9.8M.
# James (Heracles Almelo)- A 24 years old English RB with a value of £8.8M.
# Estupiñán (Heracles Almelo)- A 26 years old Ecuadorean LB with a value of £7.5M.
# Roger Ibañez (Heracles Almelo)- A 25 years old Brazilian CB with a value of £6.6M.
# Trubin (Heracles Almelo)- A 23 years old Ukrainian GK with a value of £5.5M.
# T. Bruns (Heracles Almelo)- A 32 years old Dutch CAM with a value of £1.4M.
# Scheperman (Heracles Almelo)- A 22 years old Dutch CDM with a value of £1.2M.
# van Oorschot (Heracles Almelo)- A 18 years old Dutch ST with a value of £1.2M.
# Mesik (Heracles Almelo)- A 23 years old Slovak CB with a value of £851K.
# Mantel (Heracles Almelo)- A 23 years old Belgian GK with a value of £485K.
# Jansink (Heracles Almelo)- A 21 years old Dutch GK with a value of £475K.

# %%
# Create a pandas DataFrame
df_players = pd.DataFrame(players_data)

# %%
df = pd.concat([df, df_players], ignore_index=True)

# %%
df
# Out:
#                 Team        Player Position Nationality Age Value
# 0    Go Ahead Eagles        Openda       ST     Belgian  24  155M
# 1    Go Ahead Eagles       Zirkzee       ST       Dutch  23  128M
# 2    Go Ahead Eagles  Lamine Yamal       RW     Spanish  17  116M
# 3    Go Ahead Eagles    Kulusevski       RW     Swedish  24  113M
# 4    Go Ahead Eagles          Leão       LW  Portuguese  25  112M
# ..               ...           ...      ...         ...  ..   ...
# 334  Heracles Almelo    Scheperman      CDM       Dutch  22  1.2M
# 335  Heracles Almelo  van Oorschot       ST       Dutch  18  1.2M
# 336  Heracles Almelo         Mesik       CB      Slovak  23  851K
# 337  Heracles Almelo        Mantel       GK     Belgian  23  485K
# 338  Heracles Almelo       Jansink       GK       Dutch  21  475K
#
# [339 rows x 6 columns]

# %%
df['Team'].nunique()
# Out:
# 18

# %%
df.sort_values(by='Age', ascending=True).head(40)
# Out:
#                  Team                  Player Position Nationality Age  Value
# 2     Go Ahead Eagles            Lamine Yamal       RW     Spanish  17   116M
# 335   Heracles Almelo            van Oorschot       ST       Dutch  18   1.2M
# 319         Willem II                   Razak       RW       Dutch  18   1.4M
# 265               PSV                    Land       CM       Dutch  18   4.1M
# 51      SC Heerenveen              Klaverboer       GK       Dutch  18   2.2M
# 34    Go Ahead Eagles               S. Jansen       GK       Dutch  19   509K
# 35    Go Ahead Eagles                 Verdoni       GK       Dutch  19   487K
# 175         Feyenoord                 Milambo       CM       Dutch  19   7.9M
# 232         NAC Breda                  Rached       ST    Moroccan  19   1.2M
# 230         NAC Breda                 Kumbedi       RB      French  19   2.4M
# 212        PEC Zwolle                  Ruward       CB       Dutch  19   1.1M
# 226         NAC Breda                Morgalla       RB      German  19   4.7M
# 207        PEC Zwolle            van der Haar       CB       Dutch  20   1.4M
# 111                AZ                    Goes       CB       Dutch  20   3.8M
# 28    Go Ahead Eagles                 Saathof       RB       Dutch  20   1.4M
# 178         Feyenoord                 Zechiël      CDM       Dutch  20   1.4M
# 118      NEC Nijmegen                    Sano       LW    Japanese  20  24.9M
# 147  Sparta Rotterdam               Reitmaier       GK      German  20   758K
# 136  Sparta Rotterdam                  Gnonto       RW     Italian  20   6.9M
# 179         Feyenoord                 van Sas       GK       Dutch  20   805K
# 208        PEC Zwolle                  Bobson       RW       Dutch  20   1.3M
# 214        PEC Zwolle                  Kroeze       CB       Dutch  20   654K
# 40      SC Heerenveen                   Sávio       RW   Brazilian  20  93.3M
# 217        PEC Zwolle                 Verduin       GK       Dutch  20   481K
# 218         NAC Breda                   Brady       GK    American  20  22.9M
# 105                AZ            Marlon Gomes       CM   Brazilian  20   4.8M
# 98                 AZ              van Bommel       LW       Dutch  20   7.8M
# 84        Almere City  Ritmeester van de Kamp       CM       Dutch  20   1.7M
# 10    Go Ahead Eagles                    Gavi       CM     Spanish  20   159M
# 233         NAC Breda                   Jaddi       CM       Dutch  20   774K
# 210        PEC Zwolle              Fichtinger      CDM       Dutch  20   1.3M
# 132      NEC Nijmegen                   Roefs       GK       Dutch  21   3.8M
# 82        Almere City                  Resink       CM       Dutch  21   1.8M
# 52      SC Heerenveen                   Smans      CAM       Dutch  21   1.7M
# 169         Feyenoord               Camavinga       CM      French  21  17.0M
# 198        PEC Zwolle         García MacNulty       LB       Irish  21   2.2M
# 144  Sparta Rotterdam                    Mito       RW    Japanese  21   2.8M
# 162         Feyenoord              Bellingham      CAM     English  21  46.6M
# 177         Feyenoord                Tsoungui       CB     Belgian  21   1.7M
# 182         FC Twente                 Højlund       ST      Danish  21  17.4M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Team         339 non-null    object
#  1   Player       339 non-null    object
#  2   Position     339 non-null    object
#  3   Nationality  339 non-null    object
#  4   Age          339 non-null    object
#  5   Value        339 non-null    object
# dtypes: object(6)
# memory usage: 16.0+ KB

# %%
df['Age'] = df['Age'].astype(int)

# %%
df.groupby('Team')['Age'].mean().sort_values()
# Out:
# Team
# NAC Breda           21.647059
# AZ                  24.055556
# PEC Zwolle          24.142857
# Heracles Almelo     24.187500
# Feyenoord           24.263158
# Almere City         24.277778
# Sparta Rotterdam    24.428571
# SC Heerenveen       24.888889
# Go Ahead Eagles     24.916667
# PSV                 25.823529
# RKC Waalwijk        26.153846
# NEC Nijmegen        26.210526
# FC Groningen        26.687500
# FC Twente           27.176471
# Willem II           27.190476
# Ajax                28.200000
# FC Utrecht          28.789474
# Fortuna Sittard     28.933333
# Name: Age, dtype: float64

# %%
df.to_csv("D:\Webscraping\player_team.csv", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\hoybr\AppData\Local\Temp\ipykernel_26388\3475755401.py:1: SyntaxWarning: invalid escape sequence '\W'
#   df.to_csv("D:\Webscraping\player_team.csv", index=False)

# %%
# Closing webdriver
driver.quit()
